# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
from matplotlib.pyplot import figure
from scipy.stats.mstats import winsorize
from scipy.stats import boxcox
import itertools
import math
from scipy.stats import jarque_bera
from scipy.stats import normaltest
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import normalize
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error
from statsmodels.tools.eval_measures import mse, rmse
import statsmodels.api as sm
from sklearn import neighbors
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import LassoCV
from sklearn.linear_model import ElasticNetCV
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/usedcar-data/CarDetails_DataDescription.docx
# /kaggle/input/usedcar-data/UserCarData.csv

# %%
usedcars_df = pd.DataFrame()
usedcars_df = pd.read_csv("/kaggle/input/usedcar-data/UserCarData.csv")
usedcars_df
# Out:
#       Sales_ID     name  year  selling_price  km_driven   Region  \
# 0            1   Maruti  2014         450000     145500     East
# 1            2    Skoda  2014         370000     120000     East
# 2            3    Honda  2006         158000     140000  Central
# 3            4  Hyundai  2010         225000     127000  Central
# 4            5   Maruti  2007         130000     120000     East
# ...        ...      ...   ...            ...        ...      ...
# 7901      8124  Hyundai  2013         320000     110000  Central
# 7902      8125  Hyundai  2007         135000     119000  Central
# 7903      8126   Maruti  2009         382000     120000  Central
# 7904      8127     Tata  2013         290000      25000     East
# 7905      8128     Tata  2013         290000      25000     East
#
#          State or Province           City    fuel seller_type transmission  \
# 0     District of Columbia     Washington  Diesel  Individual       Manual
# 1                 New York  New York City  Diesel  Individual       Manual
# 2                 Illinois        Chicago  Petrol  Individual       Manual
# 3                 Illinois        Chicago  Diesel  Individual       Manual
# 4                 New York  New York City  Petrol  Individual       Manual
# ...                    ...            ...     ...         ...          ...
# 7901                 Texas          Plano  Petrol  Individual       Manual
# 7902                 Texas    Port Arthur  Diesel  Individual       Manual
# 7903                 Texas    Port Arthur  Diesel  Individual       Manual
# 7904         Massachusetts      Lunenburg  Diesel  Individual       Manual
# 7905                 Maine        Augusta  Diesel  Individual       Manual
#
#                    owner  mileage  engine  max_power  \
# 0            First_Owner    23.40    1248      74.00
# 1           Second_Owner    21.14    1498     103.52
# 2            Third_Owner    17.70    1497      78.00
# 3            First_Owner    23.00    1396      90.00
# 4            First_Owner    16.10    1298      88.20
# ...                  ...      ...     ...        ...
# 7901         First_Owner    18.50    1197      82.85
# 7902  Fourth_Above_Owner    16.80    1493     110.00
# 7903         First_Owner    19.30    1248      73.90
# 7904         First_Owner    23.57    1396      70.00
# 7905         First_Owner    23.57    1396      70.00
#
#                          torque  seats sold
# 0                190Nm@ 2000rpm      5    Y
# 1           250Nm@ 1500-2500rpm      5    Y
# 2         12.7@ 2,700(kgm@ rpm)      5    Y
# 3      22.4 kgm at 1750-2750rpm      5    Y
# 4         11.5@ 4,500(kgm@ rpm)      5    Y
# ...                         ...    ...  ...
# 7901           113.7Nm@ 4000rpm      5    N
# 7902  24@ 1,900-2,750(kgm@ rpm)      5    N
# 7903             190Nm@ 2000rpm      5    N
# 7904        140Nm@ 1800-3000rpm      5    N
# 7905        140Nm@ 1800-3000rpm      5    N
#
# [7906 rows x 18 columns]

# %%
# Fetching DataFrame details like dimension etc,.
usedcars_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7906 entries, 0 to 7905
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sales_ID           7906 non-null   int64
#  1   name               7906 non-null   object
#  2   year               7906 non-null   int64
#  3   selling_price      7906 non-null   int64
#  4   km_driven          7906 non-null   int64
#  5   Region             7906 non-null   object
#  6   State or Province  7906 non-null   object
#  7   City               7906 non-null   object
#  8   fuel               7906 non-null   object
#  9   seller_type        7906 non-null   object
#  10  transmission       7906 non-null   object
#  11  owner              7906 non-null   object
#  12  mileage            7906 non-null   float64
#  13  engine             7906 non-null   int64
#  14  max_power          7906 non-null   float64
#  15  torque             7906 non-null   object
#  16  seats              7906 non-null   int64
#  17  sold               7906 non-null   object
# dtypes: float64(2), int64(6), object(10)
# memory usage: 1.1+ MB

# %%
usedcars_df.describe()
# Out:
#           Sales_ID         year  selling_price     km_driven      mileage  \
# count  7906.000000  7906.000000   7.906000e+03  7.906000e+03  7906.000000
# mean   4070.106248  2013.983936   6.498137e+05  6.918866e+04    19.419861
# std    2345.770159     3.863695   8.135827e+05  5.679230e+04     4.036263
# min       1.000000  1994.000000   2.999900e+04  1.000000e+00     0.000000
# 25%    2037.250000  2012.000000   2.700000e+05  3.500000e+04    16.780000
# 50%    4076.500000  2015.000000   4.500000e+05  6.000000e+04    19.300000
# 75%    6102.000000  2017.000000   6.900000e+05  9.542500e+04    22.320000
# max    8128.000000  2020.000000   1.000000e+07  2.360457e+06    42.000000
#
#             engine    max_power        seats
# count  7906.000000  7906.000000  7906.000000
# mean   1458.708829    91.587374     5.416393
# std     503.893057    35.747216     0.959208
# min     624.000000    32.800000     2.000000
# 25%    1197.000000    68.050000     5.000000
# 50%    1248.000000    82.000000     5.000000
# 75%    1582.000000   102.000000     5.000000
# max    3604.000000   400.000000    14.000000

# %% [markdown]
# ##### No.of unique values in each feature

# %%
col_list = list(usedcars_df.columns)
for col in col_list:
    print('{} :'.format(col), usedcars_df[col].nunique())
# Out:
# Sales_ID : 7906
# name : 31
# year : 27
# selling_price : 670
# km_driven : 898
# Region : 4
# State or Province : 49
# City : 1310
# fuel : 4
# seller_type : 3
# transmission : 2
# owner : 5
# mileage : 381
# engine : 121
# max_power : 318
# torque : 441
# seats : 9
# sold : 2

# %% [markdown]
# ## Data Cleaning
#
# #### Identifying Features with more than 40% Missing Values

# %%
usedcars_missing_df = pd.concat([(usedcars_df.isnull().sum()*100/usedcars_df.isnull().count()).sort_values(ascending=False)], axis=1, keys=["percentage"])
usedcars_missing_df[usedcars_missing_df["percentage"] > 10]
# Out:
# Empty DataFrame
# Columns: [percentage]
# Index: []

# %% [markdown]
# No Missing Values
#
# ##### Creating Numeric and Non Numeric feature lists

# %%
print(usedcars_df.select_dtypes(['float64', 'int64']).columns)
print(usedcars_df.select_dtypes('object').columns)

# target Feature is 'selling_price'
# Out:
# Index(['Sales_ID', 'year', 'selling_price', 'km_driven', 'mileage', 'engine',
#        'max_power', 'seats'],
#       dtype='object')
# Index(['name', 'Region', 'State or Province', 'City', 'fuel', 'seller_type',
#        'transmission', 'owner', 'torque', 'sold'],
#       dtype='object')

# %%
usedcars_col_list = ['selling_price', 'mileage', 'engine', 'max_power']

# %% [markdown]
# The Torque variable is a string and has 2 metrics, force with multiple units like Nm & kgm and rpm (constant & range) in a single variable. to consider this variable it involves data manipulation like converting Nm to Kgm & vice versa, Convert RPM range value to constant and data standardization. Considering all the above transformation changes, we will be dropping the Torque Variable.
#
# Similarly the State or Province & City fields are also not necessary for predicting the selling price.

# %%
usedcars_df = usedcars_df.drop(['km_driven', 'Region', 'name', 'torque', 'State or Province', 'City','seller_type', 'sold', 'transmission','owner','fuel'],axis=1)

# %%
usedcars_cat_list = ['year', 'seats']

# %%
# Identifying Zero values
for col in usedcars_col_list:
    print('{}: '.format(col),usedcars_df[usedcars_df[col] == 0].year.count())
    #.replace(0,np.nan,inplace=True)
   # diabetes_df[col].fillna(diabetes_df[col].median(),inplace=True)
# Out:
# selling_price:  0
# mileage:  17
# engine:  0
# max_power:  0

# %%
# Used Car mileage by Sale ID

figure(figsize=(25,6), dpi=200)
plt.plot(usedcars_df['Sales_ID'], usedcars_df['mileage'], 'c^--')
plt.title('Display vehicle mileage values for each sale')
plt.ylabel('count')
plt.xlabel('Sales_ID')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Looking at the above plot and the metrics, there are few samples with mileage as zero values.
#
# ### Identifying Outliers

# %%
# Replacing 0 values with median as log(0) is infinite which cannot be plotted later after log transformation
for col in usedcars_col_list:
    usedcars_df[col].replace(0,np.nan,inplace=True)
    usedcars_df[col].fillna(usedcars_df[col].median(),inplace=True)

# %%
# Used Car mileage by Sale ID

figure(figsize=(25,6), dpi=200)
plt.plot(usedcars_df['Sales_ID'], usedcars_df['mileage'], 'c^--')
plt.title('Display vehicle mileage values for each sale')
plt.ylabel('count')
plt.xlabel('Sales_ID')
plt.xticks(rotation=90)
plt.show()

# %%
# Dropping Sales_ID which is not necessary

usedcars_df = usedcars_df.drop(['Sales_ID'],axis=1)

# %%
# Checking if there are any outliers using Box Plot for continuous variables

fig = plt.figure(figsize = (15,15))

for i, col in enumerate(usedcars_col_list):
    plt.subplot(len(usedcars_col_list),4,i+1)
    plt.boxplot(usedcars_df[col])
    plt.title("Box Plot of {}".format(col))
fig.tight_layout()
plt.show()

# %%
# Checking Normality for continuous variables
fig = plt.figure(figsize = (15,15))

for i, col in enumerate(usedcars_col_list):
    plt.subplot(len(usedcars_col_list),4,i+1)
    plt.hist(usedcars_df[col])
    plt.title("Histogram of {}".format(col))
fig.tight_layout()
plt.show()

# %% [markdown]
# None of the continuous variables are normally distributed

# %%
# Statistical methods to detect outliers
# Z-Score method 
from scipy.stats import zscore
for col in usedcars_col_list:
    z_scores = zscore(usedcars_df[col])
    print(col)
    threshold = 3
    print("The score threshold is: {}".format(threshold))
    print("The indices of the outliers:")
    print(np.where(z_scores > threshold))
    print("Number of outliers is: {}".format(len((np.where(z_scores > threshold)[0]))))
    print(40*"--")
# Out:
# selling_price
# The score threshold is: 3
# The indices of the outliers:
# (array([ 126,  127,  128,  129,  130,  131,  132,  133,  139,  142,  164,
#         278,  358,  359,  361,  371,  372,  396,  397,  399,  409,  410,
#         628,  629,  631,  641,  642, 1026, 1040, 1047, 1048, 1050, 1060,
#        1061, 1066, 1067, 1069, 1079, 1080, 1085, 1086, 1088, 1098, 1099,
#        1104, 1105, 1107, 1117, 1118, 1482, 1513, 1514, 1515, 1516, 1660,
#        1661, 1663, 1673, 1674, 1767, 1774, 1776, 1780, 1803, 1804, 1805,
#        1806, 1817, 1818, 1920, 1934, 2545, 2546, 2548, 2558, 2559, 2578,
#        2579, 2581, 2591, 2592, 2618, 2740, 2846, 2983, 2984, 2986, 2996,
#        2997, 3136, 3137, 3138, 3139, 3140, 3141, 3148, 3151, 3304, 3305,
#        3307, 3317, 3318, 3408, 3409, 3411, 3421, 3422, 3716, 3717, 3719,
#        3729, 3730, 3960, 3978, 4093, 4094, 4096, 4106, 4107, 4112, 4113,
#        4115, 4125, 4126, 4132, 4133, 4135, 4145, 4146, 4196, 4197, 4199,
#        4209, 4210, 4238, 4288, 4289, 4291, 4301, 4302, 4537, 4617, 4630,
#        4680, 4681, 4683, 4693, 4694, 4811, 4812, 4813, 4941, 4942, 4944,
#        4954, 4955, 5044, 5101, 5102, 5103, 5104, 5108, 5109, 5112, 5113,
#        5114, 5115, 5357, 5459, 5460, 5462, 5472, 5473, 5491, 5657, 5872,
#        5994, 5995, 5997, 6007, 6008, 6040, 6042, 6044, 6085, 6288, 6373,
#        6374, 6376, 6386, 6387, 6392, 6393, 6395, 6405, 6406, 6505, 6506,
#        6508, 6518, 6519, 6767, 6768, 6770, 6780, 6781, 7125, 7136, 7139,
#        7142, 7297, 7307, 7382, 7446, 7484, 7486, 7487, 7488, 7494, 7495,
#        7496, 7498, 7540, 7641, 7642, 7644, 7654, 7655, 7712]),)
# Number of outliers is: 229
# --------------------------------------------------------------------------------
# mileage
# The score threshold is: 3
# The indices of the outliers:
# (array([  33,  164, 2239, 3790, 5626, 5650, 7332]),)
# Number of outliers is: 7
# --------------------------------------------------------------------------------
# engine
# The score threshold is: 3
# The indices of the outliers:
# (array([  45,   73,  129,  131,  142,  181,  255,  454,  456,  609,  663,
#         876, 1009, 1026, 1040, 1482, 1516, 1626, 1762, 1776, 1806, 1852,
#        1868, 2070, 2454, 2571, 2615, 2618, 2634, 2734, 2737, 2775, 2846,
#        2881, 3114, 3139, 3148, 3530, 3754, 3960, 3978, 4073, 4268, 4395,
#        4546, 4572, 4617, 4630, 4651, 4802, 4814, 4841, 4980, 5104, 5114,
#        5138, 5374, 5452, 5548, 5657, 5793, 5816, 6044, 6085, 6106, 6288,
#        6415, 6814, 7014, 7135, 7297, 7382, 7488, 7498, 7532, 7575, 7591,
#        7623]),)
# Number of outliers is: 78
# --------------------------------------------------------------------------------
# max_power
# The score threshold is: 3
# The indices of the outliers:
# (array([ 127,  129,  131,  135,  140,  142,  164,  358,  396,  609,  628,
#         662, 1026, 1029, 1040, 1047, 1066, 1085, 1104, 1514, 1516, 1660,
#        1804, 1806, 2065, 2067, 2070, 2071, 2545, 2578, 2618, 2634, 2737,
#        2846, 2983, 3137, 3139, 3148, 3219, 3304, 3355, 3408, 3716, 3899,
#        3960, 3963, 3978, 4093, 4112, 4132, 4196, 4248, 4288, 4558, 4617,
#        4630, 4636, 4651, 4680, 4743, 4801, 4941, 5008, 5102, 5104, 5114,
#        5251, 5374, 5459, 5548, 5657, 5793, 5816, 5994, 6085, 6373, 6392,
#        6415, 6505, 6767, 7297, 7307, 7382, 7486, 7488, 7498, 7558, 7591,
#        7641, 7701]),)
# Number of outliers is: 90
# --------------------------------------------------------------------------------

# %%
# Tukey's Method (Values outside the threshold of 1.5)
for col in usedcars_col_list:
    print(col)
    q75, q25 = np.percentile(usedcars_df[col], [75 ,25])
    iqr = q75 - q25
    threshold = 2
    min_val = q25 - (iqr*threshold)
    max_val = q75 + (iqr*threshold)
    print("The score threshold is: {}".format(threshold))
    print("Number of outliers is: {}".format(
        len((np.where((usedcars_df[col] > max_val) 
                      | (usedcars_df[col] < min_val))[0]))
    ))
    print(40*"--")
# Out:
# selling_price
# The score threshold is: 2
# Number of outliers is: 517
# --------------------------------------------------------------------------------
# mileage
# The score threshold is: 2
# Number of outliers is: 4
# --------------------------------------------------------------------------------
# engine
# The score threshold is: 2
# Number of outliers is: 781
# --------------------------------------------------------------------------------
# max_power
# The score threshold is: 2
# Number of outliers is: 451
# --------------------------------------------------------------------------------

# %% [markdown]
# ### Log Transforming Outliers

# %%
# Box PLot of log transformed data
fig = plt.figure(figsize=(15,15))
for i, col in enumerate(usedcars_col_list):
    plt.subplot(len(usedcars_col_list), 4, i+1)
    plt.boxplot(np.log(usedcars_df[col]))
    plt.title("Boxplot of log transformed {}".format(col))
fig.tight_layout()
plt.show()

# %%
# Take the log of the variables and calculate the quartiles accordingly.
for col in usedcars_col_list:
    print(col)
    q75, q25 = np.percentile(np.log(usedcars_df[col]), [75 ,25])
    iqr = q75 - q25

    for threshold in np.arange(1,5,0.5):
        min_val = q25 - (iqr*threshold)
        max_val = q75 + (iqr*threshold)
        print("The score threshold is: {}".format(threshold))
        print("Number of outliers is: {}".format(
            len((np.where((np.log(usedcars_df[col]) > max_val) 
                      | (np.log(usedcars_df[col]) < min_val))[0]))
        ))
    print(40*("--"))
# Out:
# selling_price
# The score threshold is: 1.0
# Number of outliers is: 772
# The score threshold is: 1.5
# Number of outliers is: 377
# The score threshold is: 2.0
# Number of outliers is: 139
# The score threshold is: 2.5
# Number of outliers is: 1
# The score threshold is: 3.0
# Number of outliers is: 0
# The score threshold is: 3.5
# Number of outliers is: 0
# The score threshold is: 4.0
# Number of outliers is: 0
# The score threshold is: 4.5
# Number of outliers is: 0
# --------------------------------------------------------------------------------
# mileage
# The score threshold is: 1.0
# Number of outliers is: 262
# The score threshold is: 1.5
# Number of outliers is: 48
# The score threshold is: 2.0
# Number of outliers is: 5
# The score threshold is: 2.5
# Number of outliers is: 0
# The score threshold is: 3.0
# Number of outliers is: 0
# The score threshold is: 3.5
# Number of outliers is: 0
# The score threshold is: 4.0
# Number of outliers is: 0
# The score threshold is: 4.5
# Number of outliers is: 0
# --------------------------------------------------------------------------------
# engine
# The score threshold is: 1.0
# Number of outliers is: 1887
# The score threshold is: 1.5
# Number of outliers is: 760
# The score threshold is: 2.0
# Number of outliers is: 139
# The score threshold is: 2.5
# Number of outliers is: 12
# The score threshold is: 3.0
# Number of outliers is: 0
# The score threshold is: 3.5
# Number of outliers is: 0
# The score threshold is: 4.0
# Number of outliers is: 0
# The score threshold is: 4.5
# Number of outliers is: 0
# --------------------------------------------------------------------------------
# max_power
# The score threshold is: 1.0
# Number of outliers is: 730
# The score threshold is: 1.5
# Number of outliers is: 392
# The score threshold is: 2.0
# Number of outliers is: 42
# The score threshold is: 2.5
# Number of outliers is: 2
# The score threshold is: 3.0
# Number of outliers is: 1
# The score threshold is: 3.5
# Number of outliers is: 0
# The score threshold is: 4.0
# Number of outliers is: 0
# The score threshold is: 4.5
# Number of outliers is: 0
# --------------------------------------------------------------------------------

# %% [markdown]
# ### Univariant Analysis

# %%
# Getting discriptive statistics
usedcars_df.describe(include='all')
# Out:
#               year  selling_price      mileage       engine    max_power  \
# count  7906.000000   7.906000e+03  7906.000000  7906.000000  7906.000000
# mean   2013.983936   6.498137e+05    19.461425  1458.708829    91.587374
# std       3.863695   8.135827e+05     3.934295   503.893057    35.747216
# min    1994.000000   2.999900e+04     9.000000   624.000000    32.800000
# 25%    2012.000000   2.700000e+05    16.780000  1197.000000    68.050000
# 50%    2015.000000   4.500000e+05    19.330000  1248.000000    82.000000
# 75%    2017.000000   6.900000e+05    22.320000  1582.000000   102.000000
# max    2020.000000   1.000000e+07    42.000000  3604.000000   400.000000
#
#              seats
# count  7906.000000
# mean      5.416393
# std       0.959208
# min       2.000000
# 25%       5.000000
# 50%       5.000000
# 75%       5.000000
# max      14.000000

# %% [markdown]
# #### Univariate visualization of continuous variables

# %%
# Histogram plot of Original data
fig = plt.figure(figsize=(15,20))
for i, col in enumerate(usedcars_col_list):
    plt.subplot(len(usedcars_col_list), 4, i+1)
    plt.hist(usedcars_df[col])
    plt.title("Histogram of {}".format(col))
fig.tight_layout()
plt.show()

# %%
# Histogram of log transformed data

fig = plt.figure(figsize=(15,20))
for i, col in enumerate(usedcars_col_list):
    plt.subplot(len(usedcars_col_list), 4, i+1)
    plt.hist(np.log(usedcars_df[col]))
    plt.title("Histogram of log transformed {}".format(col))
fig.tight_layout()
plt.show()

# %% [markdown]
# The Log Transformed Data look more closely to normally distributed.

# %%
# Creating Log transformed dataset
log_usedcars_df = pd.DataFrame()
for col in usedcars_col_list:
    log_usedcars_df[col]=np.log(usedcars_df[col])

# %%
# replace log transformed selling price variable with original selling_price
log_usedcars_df = log_usedcars_df.drop(['selling_price'], axis=1)

# Adding Target Variable and other non nopn transformed data to log_diabetes_df
log_usedcars_df["selling_price"]=usedcars_df["selling_price"]

# %% [markdown]
# #### Univariate Visualization of categorical variables

# %%
# Bar chart of categorical variables

fig = plt.figure(figsize=(20,10))
for i, col in enumerate(usedcars_cat_list):
    plt.subplot(len(usedcars_cat_list), 4, i+1)
    plt.barh(usedcars_df.groupby(col)[col].count().index, usedcars_df.groupby(col)[col].count())
    plt.title("Horizontal bar chart of {}".format(col))
fig.tight_layout()
plt.show()

# %% [markdown]
# Among all categorical variables charts demonstrated above, the most important and commonly used variable for predicting the selling price are State, Fuel, seller_type, Transmission & owner. (data Imbalance) The observation counts for all these variables are not same across different categories. Example: the Transmission Bar Chart, the sample of Manual Transmission vehicles are higher than the automatic.

# %% [markdown]
# ### Bivariate analysis of two continuous variables

# %%
bi_con_list = list(itertools.combinations(usedcars_col_list,2))

fig = plt.figure(figsize=(20,50))
for i, col in enumerate(bi_con_list):
    plt.subplot(len(bi_con_list), 4, i+1)
    plt.scatter(log_usedcars_df[col[0]], log_usedcars_df[col[1]])
    plt.title("Scatter Plot of {} Vs {}".format(col[0],col[1]))
fig.tight_layout()
plt.show()

# %% [markdown]
# As per the above bivariate analysis scatter plots, the more positve relation was between selling_price, engine & max_power. which is expected. This can also be confirmed using the correlation coefficient matrix

# %% [markdown]
# ### Appling Correlation Coefficient

# %%
usedcars_df.corr()
# Out:
#                    year  selling_price   mileage    engine  max_power  \
# year           1.000000       0.412302  0.332116  0.018263   0.226598
# selling_price  0.412302       1.000000 -0.128718  0.455682   0.749674
# mileage        0.332116      -0.128718  1.000000 -0.588134  -0.384507
# engine         0.018263       0.455682 -0.588134  1.000000   0.703975
# max_power      0.226598       0.749674 -0.384507  0.703975   1.000000
# seats         -0.007923       0.041617 -0.471882  0.611103   0.191999
#
#                   seats
# year          -0.007923
# selling_price  0.041617
# mileage       -0.471882
# engine         0.611103
# max_power      0.191999
# seats          1.000000

# %% [markdown]
# ### Correlation Coefficient - Matrices view

# %%
plt.figure(figsize=(18,5))

plt.subplot(1,2,1)
sns.heatmap(log_usedcars_df.corr(), square=True, annot=True, linewidths=.5)
plt.title('correlation matrix usedcars_df')

plt.show()

# %% [markdown]
# The most correlated variables with target variable is engine & max_power

# %% [markdown]
# ### Bivariate analysis of a continuous-categorical pair

# %%
fig = plt.figure(figsize=(20,20))
for i, col in enumerate(usedcars_col_list):
    plt.subplot(len(usedcars_col_list), 4, i+1)
    sns.barplot(usedcars_df["year"], log_usedcars_df[col])
    plt.title("Bar chart of year Vs {}".format(col))
    plt.xticks(rotation = 90)
fig.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(20,20))
for i, col in enumerate(usedcars_col_list):
    plt.subplot(len(usedcars_col_list), 4, i+1)
    sns.barplot(usedcars_df["seats"], log_usedcars_df[col])
    plt.title("Bar chart of seats Vs {}".format(col))
    plt.xticks(rotation = 90)
fig.tight_layout()
plt.show()

# %% [markdown]
# As per the demonstrated Continuous-Categorical Variables the selling price varies significantly for few categorical type and for the others there isn't much difference. There is significant difference between selling prices and year & seats variables

# %%
# Test whether group differences are significant
for col in usedcars_cat_list:
    ft = usedcars_df[col].unique()
    grouped_fuel_df = usedcars_df.groupby(col)
    for var in ["selling_price"]:
        print("------------------------------------------------")
        print("Comparisons for variable: {} with {}".format(var,col))
        print("------------------------------------------------")
        for i in range(0, len(ft)):
            for j in range(i+1, len(ft)):
                print("t-test between groups {0} and {1}:".format(ft[i], ft[j]))
                print(stats.ttest_ind(
                    usedcars_df[usedcars_df[col]==ft[i]][var], 
                    usedcars_df[usedcars_df[col]==ft[j]][var]
                ))
# Out:
# ------------------------------------------------
# Comparisons for variable: selling_price with year
# ------------------------------------------------
# t-test between groups 2014 and 2006:
# Ttest_indResult(statistic=9.808810404237494, pvalue=2.1061988643437942e-21)
# t-test between groups 2014 and 2010:
# Ttest_indResult(statistic=12.132549786213138, pvalue=1.095087689424801e-31)
# t-test between groups 2014 and 2007:
# Ttest_indResult(statistic=12.38688667393929, pvalue=2.4706468374803807e-32)
# t-test between groups 2014 and 2017:
# Ttest_indResult(statistic=-10.444755005361504, pvalue=9.202211042739216e-25)
# t-test between groups 2014 and 2001:
# Ttest_indResult(statistic=3.2653521931303073, pvalue=0.001153116416162975)
# t-test between groups 2014 and 2011:
# Ttest_indResult(statistic=11.243440557425998, pvalue=6.073071763082287e-28)
# t-test between groups 2014 and 2013:
# Ttest_indResult(statistic=2.8329569822611522, pvalue=0.004683946134459236)
# t-test between groups 2014 and 2005:
# Ttest_indResult(statistic=9.165084114346387, pvalue=5.514431185187194e-19)
# t-test between groups 2014 and 2009:
# Ttest_indResult(statistic=11.976019267692841, pvalue=1.1955288932064565e-30)
# t-test between groups 2014 and 2016:
# Ttest_indResult(statistic=-7.6537377856313995, pvalue=3.509025876837206e-14)
# t-test between groups 2014 and 2012:
# Ttest_indResult(statistic=9.96007778607172, pvalue=1.5606831782776666e-22)
# t-test between groups 2014 and 2002:
# Ttest_indResult(statistic=5.09934655897439, pvalue=4.50091240582646e-07)
# t-test between groups 2014 and 2015:
# Ttest_indResult(statistic=-4.28288528006095, pvalue=1.971269156914088e-05)
# t-test between groups 2014 and 2018:
# Ttest_indResult(statistic=-12.260811287692315, pvalue=6.305420764038643e-33)
# t-test between groups 2014 and 2019:
# Ttest_indResult(statistic=-16.591548629688795, pvalue=8.036282500688406e-56)
# t-test between groups 2014 and 2008:
# Ttest_indResult(statistic=12.202017436566765, pvalue=1.3897451927696772e-31)
# t-test between groups 2014 and 2020:
# Ttest_indResult(statistic=-6.609568272995512, pvalue=7.700631285550601e-11)
# t-test between groups 2014 and 1999:
# Ttest_indResult(statistic=4.664509602107896, pvalue=3.7773493532627374e-06)
# t-test between groups 2014 and 2000:
# Ttest_indResult(statistic=4.833664166437581, pvalue=1.6841344815608463e-06)
# t-test between groups 2014 and 2003:
# Ttest_indResult(statistic=7.153943839504798, pvalue=2.2642703853876415e-12)
# t-test between groups 2014 and 2004:
# Ttest_indResult(statistic=8.233000706962823, pvalue=9.573836161230568e-16)
# t-test between groups 2014 and 1994:
# Ttest_indResult(statistic=1.782983276462392, pvalue=0.07507817318574793)
# t-test between groups 2014 and 1998:
# Ttest_indResult(statistic=3.902362335218687, pvalue=0.00010556529606315527)
# t-test between groups 2014 and 1997:
# Ttest_indResult(statistic=3.6609890361476882, pvalue=0.00027242768259953007)
# t-test between groups 2014 and 1995:
# Ttest_indResult(statistic=nan, pvalue=nan)
# t-test between groups 2014 and 1996:
# Ttest_indResult(statistic=1.9072997335075, pvalue=0.05694360516050289)
# t-test between groups 2006 and 2010:
# Ttest_indResult(statistic=-4.812573284800819, pvalue=2.00503192514001e-06)
# t-test between groups 2006 and 2007:
# Ttest_indResult(statistic=-0.5537711994308101, pvalue=0.5801887147727098)
# t-test between groups 2006 and 2017:
# Ttest_indResult(statistic=-8.573832625375857, pvalue=3.315811222125307e-17)
# t-test between groups 2006 and 2001:
# Ttest_indResult(statistic=2.337243269075078, pvalue=0.02130533469578555)
# t-test between groups 2006 and 2011:
# Ttest_indResult(statistic=-6.613308136887328, pvalue=7.685848189068636e-11)
# t-test between groups 2006 and 2013:
# Ttest_indResult(statistic=-8.13637209103466, pvalue=1.6362725951420137e-15)
# t-test between groups 2006 and 2005:
# Ttest_indResult(statistic=1.4506924045167855, pvalue=0.1486454358785884)
# t-test between groups 2006 and 2009:
# Ttest_indResult(statistic=-3.290564684862185, pvalue=0.0011076078032437018)
# t-test between groups 2006 and 2016:
# Ttest_indResult(statistic=-10.31433726708057, pvalue=1.0076657337614028e-23)
# t-test between groups 2006 and 2012:
# Ttest_indResult(statistic=-8.610186680290973, pvalue=4.5607788250154176e-17)
# t-test between groups 2006 and 2002:
# Ttest_indResult(statistic=2.1717488319192446, pvalue=0.03185853428334823)
# t-test between groups 2006 and 2015:
# Ttest_indResult(statistic=-12.440575543999502, pvalue=7.845833113199051e-33)
# t-test between groups 2006 and 2018:
# Ttest_indResult(statistic=-9.434233143406026, pvalue=3.213662988949084e-20)
# t-test between groups 2006 and 2019:
# Ttest_indResult(statistic=-8.7320007406409, pvalue=1.9134941759564018e-17)
# t-test between groups 2006 and 2008:
# Ttest_indResult(statistic=-2.111355137512193, pvalue=0.03556592565451798)
# t-test between groups 2006 and 2020:
# Ttest_indResult(statistic=-7.53910125439021, pvalue=2.501282226108539e-12)
# t-test between groups 2006 and 1999:
# Ttest_indResult(statistic=2.677675849819774, pvalue=0.008508328659433606)
# t-test between groups 2006 and 2000:
# Ttest_indResult(statistic=2.7933000594907553, pvalue=0.006113108197124831)
# t-test between groups 2006 and 2003:
# Ttest_indResult(statistic=3.123428550863316, pvalue=0.0021817557836877966)
# t-test between groups 2006 and 2004:
# Ttest_indResult(statistic=3.1290636132933463, pvalue=0.0021051710284317967)
# t-test between groups 2006 and 1994:
# Ttest_indResult(statistic=1.0713368515673527, pvalue=0.286546403539738)
# t-test between groups 2006 and 1998:
# Ttest_indResult(statistic=2.5996170290858887, pvalue=0.010625326016727605)
# t-test between groups 2006 and 1997:
# Ttest_indResult(statistic=1.9166913184856633, pvalue=0.05789565788337871)
# t-test between groups 2006 and 1995:
# Ttest_indResult(statistic=nan, pvalue=nan)
# t-test between groups 2006 and 1996:
# Ttest_indResult(statistic=1.4092453699999112, pvalue=0.16180411548363832)
# t-test between groups 2010 and 2007:
# Ttest_indResult(statistic=5.605973528310271, pvalue=3.2909427747677135e-08)
# t-test between groups 2010 and 2017:
# Ttest_indResult(statistic=-13.940434100337086, pvalue=1.9857827547601226e-41)
# t-test between groups 2010 and 2001:
# Ttest_indResult(statistic=2.695395640471943, pvalue=0.0073436585014404025)
# t-test between groups 2010 and 2011:
# Ttest_indResult(statistic=-3.3205168344204608, pvalue=0.0009329766098848604)
# t-test between groups 2010 and 2013:
# Ttest_indResult(statistic=-9.300066904827759, pvalue=8.016808552843383e-20)
# t-test between groups 2010 and 2005:
# Ttest_indResult(statistic=5.344379796416219, pvalue=1.4461962207621847e-07)
# t-test between groups 2010 and 2009:
# Ttest_indResult(statistic=2.8564334511090688, pvalue=0.004431670419017549)
# t-test between groups 2010 and 2016:
# Ttest_indResult(statistic=-15.444002030085725, pvalue=2.594562261023019e-49)
# t-test between groups 2010 and 2012:
# Ttest_indResult(statistic=-5.8386322972278855, pvalue=7.12167289947913e-09)
# t-test between groups 2010 and 2002:
# Ttest_indResult(statistic=3.577054680285741, pvalue=0.0003909574418387636)
# t-test between groups 2010 and 2015:
# Ttest_indResult(statistic=-16.81663192754243, pvalue=6.712701657578223e-57)
# t-test between groups 2010 and 2018:
# Ttest_indResult(statistic=-15.523132594038284, pvalue=1.3762976461975666e-49)
# t-test between groups 2010 and 2019:
# Ttest_indResult(statistic=-15.614861007892797, pvalue=3.9497043246965525e-49)
# t-test between groups 2010 and 2008:
# Ttest_indResult(statistic=4.207081661631667, pvalue=3.001307434983146e-05)
# t-test between groups 2010 and 2020:
# Ttest_indResult(statistic=-11.265201795454026, pvalue=4.40463181589796e-26)
# t-test between groups 2010 and 1999:
# Ttest_indResult(statistic=3.564275434834053, pvalue=0.0004104745526971258)
# t-test between groups 2010 and 2000:
# Ttest_indResult(statistic=3.699228827716629, pvalue=0.00024746871701006263)
# t-test between groups 2010 and 2003:
# Ttest_indResult(statistic=5.055214013945265, pvalue=6.492014915813636e-07)
# t-test between groups 2010 and 2004:
# Ttest_indResult(statistic=5.640381299458429, pvalue=3.1047047309781083e-08)
# t-test between groups 2010 and 1994:
# Ttest_indResult(statistic=1.3817136185515668, pvalue=0.16788223867576704)
# t-test between groups 2010 and 1998:
# Ttest_indResult(statistic=3.1359099401109702, pvalue=0.001845881605636066)
# t-test between groups 2010 and 1997:
# Ttest_indResult(statistic=2.7216784305396935, pvalue=0.006792459706228341)
# t-test between groups 2010 and 1995:
# Ttest_indResult(statistic=nan, pvalue=nan)
# t-test between groups 2010 and 1996:
# Ttest_indResult(statistic=1.5938203817993775, pvalue=0.111818736677031)
# t-test between groups 2007 and 2017:
# Ttest_indResult(statistic=-11.025716472506982, pvalue=5.642298063836899e-27)
# t-test between groups 2007 and 2001:
# Ttest_indResult(statistic=2.6443507226926597, pvalue=0.008920293258588638)
# t-test between groups 2007 and 2011:
# Ttest_indResult(statistic=-8.006651360178628, pvalue=4.558696837189871e-15)
# t-test between groups 2007 and 2013:
# Ttest_indResult(statistic=-10.22918252562507, pvalue=3.170042374533506e-23)
# t-test between groups 2007 and 2005:
# Ttest_indResult(statistic=2.1613147097160805, pvalue=0.031632297273330785)
# t-test between groups 2007 and 2009:
# Ttest_indResult(statistic=-3.4496188735802664, pvalue=0.0006207827888367529)
# t-test between groups 2007 and 2016:
# Ttest_indResult(statistic=-13.188993772750262, pvalue=8.290831015242202e-37)
# t-test between groups 2007 and 2012:
# Ttest_indResult(statistic=-10.520434314392574, pvalue=2.5598284171649823e-24)
# t-test between groups 2007 and 2002:
# Ttest_indResult(statistic=2.6201165563808395, pvalue=0.009500539035675807)
# t-test between groups 2007 and 2015:
# Ttest_indResult(statistic=-15.798785673303655, pvalue=4.471198253453209e-50)
# t-test between groups 2007 and 2018:
# Ttest_indResult(statistic=-12.143220926849894, pvalue=1.0541089468664156e-31)
# t-test between groups 2007 and 2019:
# Ttest_indResult(statistic=-11.30985058189681, pvalue=1.6695028554733154e-27)
# t-test between groups 2007 and 2008:
# Ttest_indResult(statistic=-1.9267768946322206, pvalue=0.054768863715141655)
# t-test between groups 2007 and 2020:
# Ttest_indResult(statistic=-9.651796593136071, pvalue=6.88925830817564e-19)
# t-test between groups 2007 and 1999:
# Ttest_indResult(statistic=3.099595777473135, pvalue=0.002240630914404097)
# t-test between groups 2007 and 2000:
# Ttest_indResult(statistic=3.228919512851581, pvalue=0.0014690086245636327)
# t-test between groups 2007 and 2003:
# Ttest_indResult(statistic=3.7564833262797186, pvalue=0.00022372857813889895)
# t-test between groups 2007 and 2004:
# Ttest_indResult(statistic=3.8633299451033465, pvalue=0.00014680998397933556)
# t-test between groups 2007 and 1994:
# Ttest_indResult(statistic=1.23289834852981, pvalue=0.21928640430182553)
# t-test between groups 2007 and 1998:
# Ttest_indResult(statistic=2.960346239763641, pvalue=0.0034869707486158497)
# t-test between groups 2007 and 1997:
# Ttest_indResult(statistic=2.24709583985618, pvalue=0.025848413134150792)
# t-test between groups 2007 and 1995:
# Ttest_indResult(statistic=nan, pvalue=nan)
# t-test between groups 2007 and 1996:
# Ttest_indResult(statistic=1.5901863783633159, pvalue=0.11361854449984682)
# t-test between groups 2017 and 2001:
# Ttest_indResult(statistic=2.4402491500570944, pvalue=0.014847504752974318)
# t-test between groups 2017 and 2011:
# Ttest_indResult(statistic=15.711168181692235, pvalue=8.617711374590122e-52)
# t-test between groups 2017 and 2013:
# Ttest_indResult(statistic=12.406483767087593, pvalue=7.045078887839775e-34)
# t-test between groups 2017 and 2005:
# Ttest_indResult(statistic=7.679427082672164, pvalue=3.5579674628135254e-14)
# t-test between groups 2017 and 2009:
# Ttest_indResult(statistic=11.825337153414559, pvalue=1.197610496566936e-30)
# t-test between groups 2017 and 2016:
# Ttest_indResult(statistic=5.72131223710183, pvalue=1.2288998243896162e-08)
# t-test between groups 2017 and 2012:
# Ttest_indResult(statistic=15.524148496941985, pvalue=8.588804371985736e-51)
# t-test between groups 2017 and 2002:
# Ttest_indResult(statistic=4.047340596333015, pvalue=5.56915986976295e-05)
# t-test between groups 2017 and 2015:
# Ttest_indResult(statistic=9.09450703127119, pvalue=2.4643996650170586e-19)
# t-test between groups 2017 and 2018:
# Ttest_indResult(statistic=-1.704947899523786, pvalue=0.08837536346233649)
# t-test between groups 2017 and 2019:
# Ttest_indResult(statistic=-13.01970044449117, pvalue=6.7519163237413405e-37)
# t-test between groups 2017 and 2008:
# Ttest_indResult(statistic=11.43192529926255, pvalue=8.233140953693388e-29)
# t-test between groups 2017 and 2020:
# Ttest_indResult(statistic=0.047887999572565766, pvalue=0.9618143408035675)
# t-test between groups 2017 and 1999:
# Ttest_indResult(statistic=3.593076212041559, pvalue=0.00034237225613829994)
# t-test between groups 2017 and 2000:
# Ttest_indResult(statistic=3.721353227118509, pvalue=0.00020894768891554895)
# t-test between groups 2017 and 2003:
# Ttest_indResult(statistic=5.663951191252779, pvalue=1.9112450381505202e-08)
# t-test between groups 2017 and 2004:
# Ttest_indResult(statistic=6.583074392785844, pvalue=7.237782452019279e-11)
# t-test between groups 2017 and 1994:
# Ttest_indResult(statistic=1.3662905704528192, pvalue=0.1721518850658435)
# t-test between groups 2017 and 1998:
# Ttest_indResult(statistic=2.948345861782619, pvalue=0.003267829138061277)
# t-test between groups 2017 and 1997:
# Ttest_indResult(statistic=2.848262841708475, pvalue=0.004484430558561624)
# t-test between groups 2017 and 1995:
# Ttest_indResult(statistic=nan, pvalue=nan)
# t-test between groups 2017 and 1996:
# Ttest_indResult(statistic=1.4180585201442817, pvalue=0.15648213213880532)
# t-test between groups 2001 and 2011:
# Ttest_indResult(statistic=-2.9986919232513944, pvalue=0.002828862768875948)
# t-test between groups 2001 and 2013:
# Ttest_indResult(statistic=-2.8436615295689456, pvalue=0.004595370521616748)
# t-test between groups 2001 and 2005:
# Ttest_indResult(statistic=-2.1502112194834777, pvalue=0.034558228856275075)
# t-test between groups 2001 and 2009:
# Ttest_indResult(statistic=-2.8367275796264595, pvalue=0.0049556711913519335)
# t-test between groups 2001 and 2016:
# Ttest_indResult(statistic=-3.097882650479374, pvalue=0.002012408131193675)
# t-test between groups 2001 and 2012:
# Ttest_indResult(statistic=-3.6134329104705705, pvalue=0.000326470811370743)
# t-test between groups 2001 and 2002:
# Ttest_indResult(statistic=-1.7772745965823564, pvalue=0.08875124452114594)
# t-test between groups 2001 and 2015:
# Ttest_indResult(statistic=-3.930070463934037, pvalue=9.24707179477514e-05)
# t-test between groups 2001 and 2018:
# Ttest_indResult(statistic=-2.6517869887705516, pvalue=0.008163237056872726)
# t-test between groups 2001 and 2019:
# Ttest_indResult(statistic=-2.281650997618087, pvalue=0.022867106692578774)
# t-test between groups 2001 and 2008:
# Ttest_indResult(statistic=-2.7691468640817307, pvalue=0.006135895232496878)
# t-test between groups 2001 and 2020:
# Ttest_indResult(statistic=-2.158065989250255, pvalue=0.033999178252895904)
# t-test between groups 2001 and 1999:
# Ttest_indResult(statistic=-1.6741512101482094, pvalue=0.11138817713314227)
# t-test between groups 2001 and 2000:
# Ttest_indResult(statistic=-2.157818877909709, pvalue=0.043951928866799383)
# t-test between groups 2001 and 2003:
# Ttest_indResult(statistic=-2.293319202563269, pvalue=0.027029059248274142)
# t-test between groups 2001 and 2004:
# Ttest_indResult(statistic=-2.0913737974754993, pvalue=0.04112655080305749)
# t-test between groups 2001 and 1994:
# Ttest_indResult(statistic=-1.4987041034297952, pvalue=0.18460641884308662)
# t-test between groups 2001 and 1998:
# Ttest_indResult(statistic=-1.410674049836809, pvalue=0.18181971636141853)
# t-test between groups 2001 and 1997:
# Ttest_indResult(statistic=-1.120018904619188, pvalue=0.2829719402456276)
# t-test between groups 2001 and 1995:
# Ttest_indResult(statistic=nan, pvalue=nan)
# t-test between groups 2001 and 1996:
# Ttest_indResult(statistic=0.48666426339228763, pvalue=0.6437618069403261)
# t-test between groups 2011 and 2013:
# Ttest_indResult(statistic=-8.01753235803963, pvalue=2.4818190264433945e-15)
# t-test between groups 2011 and 2005:
# Ttest_indResult(statistic=6.801072993080722, pvalue=2.3746777192667434e-11)
# t-test between groups 2011 and 2009:
# Ttest_indResult(statistic=5.75912394300368, pvalue=1.2059219335218676e-08)
# t-test between groups 2011 and 2016:
# Ttest_indResult(statistic=-16.467376229243552, pvalue=6.606361585991403e-56)
# t-test between groups 2011 and 2012:
# Ttest_indResult(statistic=-2.4766386114807446, pvalue=0.013400902721267443)
# t-test between groups 2011 and 2002:
# Ttest_indResult(statistic=4.2193018163135605, pvalue=2.8385407989891515e-05)
# t-test between groups 2011 and 2015:
# Ttest_indResult(statistic=-16.673031422675102, pvalue=7.156519917596219e-57)
# t-test between groups 2011 and 2018:
# Ttest_indResult(statistic=-17.603467670029712, pvalue=1.0466525109816965e-62)
# t-test between groups 2011 and 2019:
# Ttest_indResult(statistic=-18.57974368927853, pvalue=1.3479494876005413e-67)
# t-test between groups 2011 and 2008:
# Ttest_indResult(statistic=6.886383200169872, pvalue=1.189934871857253e-11)
# t-test between groups 2011 and 2020:
# Ttest_indResult(statistic=-11.899846568616994, pvalue=1.2017355824231478e-29)
# t-test between groups 2011 and 1999:
# Ttest_indResult(statistic=4.073329559130302, pvalue=5.277044745964327e-05)
# t-test between groups 2011 and 2000:
# Ttest_indResult(statistic=4.22503154113846, pvalue=2.772110908930457e-05)
# t-test between groups 2011 and 2003:
# Ttest_indResult(statistic=5.9466916097342715, pvalue=4.6278232764466434e-09)
# t-test between groups 2011 and 2004:
# Ttest_indResult(statistic=6.7170062078967545, pvalue=4.207900751443678e-11)
# t-test between groups 2011 and 1994:
# Ttest_indResult(statistic=1.5710770961597564, pvalue=0.1167196463444819)
# t-test between groups 2011 and 1998:
# Ttest_indResult(statistic=3.520848391954065, pvalue=0.00046414183303710853)
# t-test between groups 2011 and 1997:
# Ttest_indResult(statistic=3.1417323252592224, pvalue=0.0017656022715319304)
# t-test between groups 2011 and 1995:
# Ttest_indResult(statistic=nan, pvalue=nan)
# t-test between groups 2011 and 1996:
# Ttest_indResult(statistic=1.765860183670684, pvalue=0.07795459434900935)
# t-test between groups 2013 and 2005:
# Ttest_indResult(statistic=7.70401024853013, pvalue=4.228755662785734e-14)
# t-test between groups 2013 and 2009:
# Ttest_indResult(statistic=9.56630903226041, pvalue=1.0354237424954688e-20)
# t-test between groups 2013 and 2016:
# Ttest_indResult(statistic=-10.236338476233746, pvalue=7.905295485238133e-24)
# t-test between groups 2013 and 2012:
# Ttest_indResult(statistic=6.552850415922124, pvalue=8.144898276119023e-11)
# t-test between groups 2013 and 2002:
# Ttest_indResult(statistic=4.357742510193251, pvalue=1.5155907716560848e-05)
# t-test between groups 2013 and 2015:
# Ttest_indResult(statistic=-7.3831016617720655, pvalue=2.604470365830167e-13)
# t-test between groups 2013 and 2018:
# Ttest_indResult(statistic=-14.254828187495225, pvalue=2.7601583456487706e-43)
# t-test between groups 2013 and 2019:
# Ttest_indResult(statistic=-17.953811936120672, pvalue=2.6844129610214096e-64)
# t-test between groups 2013 and 2008:
# Ttest_indResult(statistic=9.913560481538685, pvalue=5.115951948438745e-22)
# t-test between groups 2013 and 2020:
# Ttest_indResult(statistic=-7.693553413733043, pvalue=4.5752018984537616e-14)
# t-test between groups 2013 and 1999:
# Ttest_indResult(statistic=4.024161380783354, pvalue=6.360004522593509e-05)
# t-test between groups 2013 and 2000:
# Ttest_indResult(statistic=4.170716032027659, pvalue=3.4290104919953854e-05)
# t-test between groups 2013 and 2003:
# Ttest_indResult(statistic=6.118673964927439, pvalue=1.5667298712134517e-09)
# t-test between groups 2013 and 2004:
# Ttest_indResult(statistic=7.021028708443085, pvalue=5.1183596131329735e-12)
# t-test between groups 2013 and 1994:
# Ttest_indResult(statistic=1.5406877653774043, pvalue=0.1238663465947317)
# t-test between groups 2013 and 1998:
# Ttest_indResult(statistic=3.3869965875907364, pvalue=0.000747628237045412)
# t-test between groups 2013 and 1997:
# Ttest_indResult(statistic=3.148642641713146, pvalue=0.0017126211395660233)
# t-test between groups 2013 and 1995:
# Ttest_indResult(statistic=nan, pvalue=nan)
# t-test between groups 2013 and 1996:
# Ttest_indResult(statistic=1.663587744128233, pvalue=0.09666386708636805)
# t-test between groups 2005 and 2009:
# Ttest_indResult(statistic=-4.377560453402267, pvalue=1.650864755224173e-05)
# t-test between groups 2005 and 2016:
# Ttest_indResult(statistic=-9.367598170333448, pvalue=5.44561791190488e-20)
# t-test between groups 2005 and 2012:
# Ttest_indResult(statistic=-8.637509060194827, pvalue=3.919577021301208e-17)
# t-test between groups 2005 and 2002:
# Ttest_indResult(statistic=1.4901853760534252, pvalue=0.13955934613274604)
# t-test between groups 2005 and 2015:
# Ttest_indResult(statistic=-11.459225947678194, pvalue=2.2774972303302865e-28)
# t-test between groups 2005 and 2018:
# Ttest_indResult(statistic=-8.425097390398772, pvalue=1.457787876399682e-16)
# t-test between groups 2005 and 2019:
# Ttest_indResult(statistic=-7.663722759084715, pvalue=6.507609260946222e-14)
# t-test between groups 2005 and 2008:
# Ttest_indResult(statistic=-3.4565389064266596, pvalue=0.0006337166570949947)
# t-test between groups 2005 and 2020:
# Ttest_indResult(statistic=-6.7836134402153325, pvalue=2.6231605587281434e-10)
# t-test between groups 2005 and 1999:
# Ttest_indResult(statistic=2.231754600955017, pvalue=0.028171266643782906)
# t-test between groups 2005 and 2000:
# Ttest_indResult(statistic=2.3381954217900796, pvalue=0.021618427039767546)
# t-test between groups 2005 and 2003:
# Ttest_indResult(statistic=2.1845865667733215, pvalue=0.031021971943536716)
# t-test between groups 2005 and 2004:
# Ttest_indResult(statistic=1.957126942255041, pvalue=0.052561423058377986)
# t-test between groups 2005 and 1994:
# Ttest_indResult(statistic=0.9151885374035424, pvalue=0.36298733294135066)
# t-test between groups 2005 and 1998:
# Ttest_indResult(statistic=2.3251389156988855, pvalue=0.022506460168217578)
# t-test between groups 2005 and 1997:
# Ttest_indResult(statistic=1.5154628205006277, pvalue=0.13345451733679828)
# t-test between groups 2005 and 1995:
# Ttest_indResult(statistic=nan, pvalue=nan)
# t-test between groups 2005 and 1996:
# Ttest_indResult(statistic=1.3116139973016308, pvalue=0.1935988992459185)
# t-test between groups 2009 and 2016:
# Ttest_indResult(statistic=-13.696206368152644, pvalue=1.6804807308760083e-39)
# t-test between groups 2009 and 2012:
# Ttest_indResult(statistic=-8.260653973993099, pvalue=5.525977971230398e-16)
# t-test between groups 2009 and 2002:
# Ttest_indResult(statistic=3.4303790015158793, pvalue=0.0007058493315340457)
# t-test between groups 2009 and 2015:
# Ttest_indResult(statistic=-15.8247327157645, pvalue=1.5874985234256653e-50)
# t-test between groups 2009 and 2018:
# Ttest_indResult(statistic=-13.1021139555154, pvalue=2.1171932091050257e-36)
# t-test between groups 2009 and 2019:
# Ttest_indResult(statistic=-12.653854405012819, pvalue=1.2632003270828352e-33)
# t-test between groups 2009 and 2008:
# Ttest_indResult(statistic=1.6119378328134224, pvalue=0.10770916133164238)
# t-test between groups 2009 and 2020:
# Ttest_indResult(statistic=-10.147569747339656, pvalue=5.080015179120414e-21)
# t-test between groups 2009 and 1999:
# Ttest_indResult(statistic=3.6032501993522676, pvalue=0.0003811197967146735)
# t-test between groups 2009 and 2000:
# Ttest_indResult(statistic=3.7443130593247056, pvalue=0.00022569002409495839)
# t-test between groups 2009 and 2003:
# Ttest_indResult(statistic=4.867711228628742, pvalue=1.9378208187866258e-06)
# t-test between groups 2009 and 2004:
# Ttest_indResult(statistic=5.298046898624086, pvalue=2.3731433425303545e-07)
# t-test between groups 2009 and 1994:
# Ttest_indResult(statistic=1.4085635895667126, pvalue=0.16030878336948415)
# t-test between groups 2009 and 1998:
# Ttest_indResult(statistic=3.25718628772708, pvalue=0.0012892205594783159)
# t-test between groups 2009 and 1997:
# Ttest_indResult(statistic=2.7061727834152163, pvalue=0.0072990587624025376)
# t-test between groups 2009 and 1995:
# Ttest_indResult(statistic=nan, pvalue=nan)
# t-test between groups 2009 and 1996:
# Ttest_indResult(statistic=1.6872419264676535, pvalue=0.0929066473860546)
# t-test between groups 2016 and 2012:
# Ttest_indResult(statistic=15.840730990707646, pvalue=2.5956549323527748e-52)
# t-test between groups 2016 and 2002:
# Ttest_indResult(statistic=5.028593549876556, pvalue=5.996989640619293e-07)
# t-test between groups 2016 and 2015:
# Ttest_indResult(statistic=4.717922078918814, pvalue=2.5863319213567565e-06)
# t-test between groups 2016 and 2018:
# Ttest_indResult(statistic=-7.575573026863653, pvalue=5.905154538237957e-14)
# t-test between groups 2016 and 2019:
# Ttest_indResult(statistic=-16.082501781630373, pvalue=1.2161425351793561e-53)
# t-test between groups 2016 and 2008:
# Ttest_indResult(statistic=13.455559052920217, pvalue=3.3208082185973445e-38)
# t-test between groups 2016 and 2020:
# Ttest_indResult(statistic=-2.7135650416091703, pvalue=0.00677969324615142)
# t-test between groups 2016 and 1999:
# Ttest_indResult(statistic=4.511687122104973, pvalue=7.3161244800727584e-06)
# t-test between groups 2016 and 2000:
# Ttest_indResult(statistic=4.6736442398268645, pvalue=3.428292294831789e-06)
# t-test between groups 2016 and 2003:
# Ttest_indResult(statistic=7.043343584803505, pvalue=3.7521827545517195e-12)
# t-test between groups 2016 and 2004:
# Ttest_indResult(statistic=8.158520473445165, pvalue=1.1285426603090685e-15)
# t-test between groups 2016 and 1994:
# Ttest_indResult(statistic=1.718795890523089, pvalue=0.08601310215492843)
# t-test between groups 2016 and 1998:
# Ttest_indResult(statistic=3.728034828739053, pvalue=0.00020556242319839786)
# t-test between groups 2016 and 1997:
# Ttest_indResult(statistic=3.5638278711100653, pvalue=0.00038553587682389084)
# t-test between groups 2016 and 1995:
# Ttest_indResult(statistic=nan, pvalue=nan)
# t-test between groups 2016 and 1996:
# Ttest_indResult(statistic=1.8036037593434113, pvalue=0.0716449365467854)
# t-test between groups 2012 and 2002:
# Ttest_indResult(statistic=5.218594643549623, pvalue=2.441426400774994e-07)
# t-test between groups 2012 and 2015:
# Ttest_indResult(statistic=-15.569500766318571, pvalue=1.625896573794579e-50)
# t-test between groups 2012 and 2018:
# Ttest_indResult(statistic=-17.507587613160357, pvalue=2.593045597855829e-62)
# t-test between groups 2012 and 2019:
# Ttest_indResult(statistic=-18.98951740770773, pvalue=1.5807490975154763e-70)
# t-test between groups 2012 and 2008:
# Ttest_indResult(statistic=9.401225763595516, pvalue=5.2415662508202857e-20)
# t-test between groups 2012 and 2020:
# Ttest_indResult(statistic=-11.866614037723341, pvalue=1.0659577856010037e-29)
# t-test between groups 2012 and 1999:
# Ttest_indResult(statistic=4.969886249255681, pvalue=8.633846259156496e-07)
# t-test between groups 2012 and 2000:
# Ttest_indResult(statistic=5.153936266619329, pvalue=3.412013027546852e-07)
# t-test between groups 2012 and 2003:
# Ttest_indResult(statistic=7.3457096688866965, pvalue=6.096461955506936e-13)
# t-test between groups 2012 and 2004:
# Ttest_indResult(statistic=8.333349218660386, pvalue=4.446259858528883e-16)
# t-test between groups 2012 and 1994:
# Ttest_indResult(statistic=1.912699048060019, pvalue=0.05624627194215313)
# t-test between groups 2012 and 1998:
# Ttest_indResult(statistic=4.261139137046904, pvalue=2.3459474512724774e-05)
# t-test between groups 2012 and 1997:
# Ttest_indResult(statistic=3.8498440112236785, pvalue=0.00013029801861330335)
# t-test between groups 2012 and 1995:
# Ttest_indResult(statistic=nan, pvalue=nan)
# t-test between groups 2012 and 1996:
# Ttest_indResult(statistic=2.1236588148715265, pvalue=0.03409338169395166)
# t-test between groups 2002 and 2015:
# Ttest_indResult(statistic=-6.2619560626641855, pvalue=6.229347836454791e-10)
# t-test between groups 2002 and 2018:
# Ttest_indResult(statistic=-4.422030910864493, pvalue=1.1089296822060835e-05)
# t-test between groups 2002 and 2019:
# Ttest_indResult(statistic=-3.9258499377347005, pvalue=9.644642865454871e-05)
# t-test between groups 2002 and 2008:
# Ttest_indResult(statistic=-3.111950522072459, pvalue=0.0021072693708754373)
# t-test between groups 2002 and 2020:
# Ttest_indResult(statistic=-3.5814934956368676, pvalue=0.0005509172261407607)
# t-test between groups 2002 and 1999:
# Ttest_indResult(statistic=1.1702115666826212, pvalue=0.2508338942348393)
# t-test between groups 2002 and 2000:
# Ttest_indResult(statistic=1.2794359362472016, pvalue=0.20994302007809093)
# t-test between groups 2002 and 2003:
# Ttest_indResult(statistic=0.12066047604355863, pvalue=0.9044078106729165)
# t-test between groups 2002 and 2004:
# Ttest_indResult(statistic=-0.2819822061548321, pvalue=0.7788135850657429)
# t-test between groups 2002 and 1994:
# Ttest_indResult(statistic=0.5638421074495524, pvalue=0.5794566971432064)
# t-test between groups 2002 and 1998:
# Ttest_indResult(statistic=1.746052081416776, pvalue=0.09260935337064428)
# t-test between groups 2002 and 1997:
# Ttest_indResult(statistic=0.5480505644644985, pvalue=0.5883321577381189)
# t-test between groups 2002 and 1995:
# Ttest_indResult(statistic=nan, pvalue=nan)
# t-test between groups 2002 and 1996:
# Ttest_indResult(statistic=1.1211760294967166, pvalue=0.276184052789199)
# t-test between groups 2015 and 2018:
# Ttest_indResult(statistic=-11.102135196980575, pvalue=1.2520063723684463e-27)
# t-test between groups 2015 and 2019:
# Ttest_indResult(statistic=-17.31438876136533, pvalue=7.802653485274528e-61)
# t-test between groups 2015 and 2008:
# Ttest_indResult(statistic=15.836575696086081, pvalue=1.9551258914461006e-50)
# t-test between groups 2015 and 2020:
# Ttest_indResult(statistic=-5.5194289219766715, pvalue=4.522400951511308e-08)
# t-test between groups 2015 and 1999:
# Ttest_indResult(statistic=5.670681961756974, pvalue=1.9973920109152922e-08)
# t-test between groups 2015 and 2000:
# Ttest_indResult(statistic=5.875302813479393, pvalue=6.224735250667771e-09)
# t-test between groups 2015 and 2003:
# Ttest_indResult(statistic=8.777346884678153, pvalue=9.81283120388487e-18)
# t-test between groups 2015 and 2004:
# Ttest_indResult(statistic=10.13406265280995, pvalue=7.954906171426845e-23)
# t-test between groups 2015 and 1994:
# Ttest_indResult(statistic=2.1638605618075744, pvalue=0.030779918037471633)
# t-test between groups 2015 and 1998:
# Ttest_indResult(statistic=4.713716132748013, pvalue=2.8793153277286647e-06)
# t-test between groups 2015 and 1997:
# Ttest_indResult(statistic=4.465488737562255, pvalue=9.164882721330298e-06)
# t-test between groups 2015 and 1995:
# Ttest_indResult(statistic=nan, pvalue=nan)
# t-test between groups 2015 and 1996:
# Ttest_indResult(statistic=2.291705659024546, pvalue=0.022189996310617206)
# t-test between groups 2018 and 2019:
# Ttest_indResult(statistic=-11.05190705109309, pvalue=2.8407929040056837e-27)
# t-test between groups 2018 and 2008:
# Ttest_indResult(statistic=12.63001909134723, pvalue=4.784486725487108e-34)
# t-test between groups 2018 and 2020:
# Ttest_indResult(statistic=0.7055169364794317, pvalue=0.48067573007097775)
# t-test between groups 2018 and 1999:
# Ttest_indResult(statistic=3.9154446382807477, pvalue=9.775647421562269e-05)
# t-test between groups 2018 and 2000:
# Ttest_indResult(statistic=4.055059918282272, pvalue=5.490658074791195e-05)
# t-test between groups 2018 and 2003:
# Ttest_indResult(statistic=6.186960185682762, pvalue=9.569359342179018e-10)
# t-test between groups 2018 and 2004:
# Ttest_indResult(statistic=7.196538909893024, pvalue=1.3515028084952334e-12)
# t-test between groups 2018 and 1994:
# Ttest_indResult(statistic=1.4881777311412536, pvalue=0.1370951536752938)
# t-test between groups 2018 and 1998:
# Ttest_indResult(statistic=3.2072034261536393, pvalue=0.00139276637973857)
# t-test between groups 2018 and 1997:
# Ttest_indResult(statistic=3.106514035839393, pvalue=0.001958840825157492)
# t-test between groups 2018 and 1995:
# Ttest_indResult(statistic=nan, pvalue=nan)
# t-test between groups 2018 and 1996:
# Ttest_indResult(statistic=1.5402383339837933, pvalue=0.1238947539294344)
# t-test between groups 2019 and 2008:
# Ttest_indResult(statistic=11.985479905656941, pvalue=1.6581491256386332e-30)
# t-test between groups 2019 and 2020:
# Ttest_indResult(statistic=4.064024359330682, pvalue=5.409038863767772e-05)
# t-test between groups 2019 and 1999:
# Ttest_indResult(statistic=3.4240537176316552, pvalue=0.0006593785440806406)
# t-test between groups 2019 and 2000:
# Ttest_indResult(statistic=3.5452253977818358, pvalue=0.0004230533272196679)
# t-test between groups 2019 and 2003:
# Ttest_indResult(statistic=5.485955567298015, pvalue=6.003787154517679e-08)
# t-test between groups 2019 and 2004:
# Ttest_indResult(statistic=6.410624440964425, pvalue=2.836776397411864e-10)
# t-test between groups 2019 and 1994:
# Ttest_indResult(statistic=1.2978850307489995, pvalue=0.1948400962268925)
# t-test between groups 2019 and 1998:
# Ttest_indResult(statistic=2.776072685803895, pvalue=0.005676593378168414)
# t-test between groups 2019 and 1997:
# Ttest_indResult(statistic=2.7304606263819022, pvalue=0.006513566502389472)
# t-test between groups 2019 and 1995:
# Ttest_indResult(statistic=nan, pvalue=nan)
# t-test between groups 2019 and 1996:
# Ttest_indResult(statistic=1.3214836104477652, pvalue=0.1868585131218932)
# t-test between groups 2008 and 2020:
# Ttest_indResult(statistic=-9.919324975792644, pvalue=5.266434009122168e-20)
# t-test between groups 2008 and 1999:
# Ttest_indResult(statistic=3.41155982652829, pvalue=0.0007728051154374057)
# t-test between groups 2008 and 2000:
# Ttest_indResult(statistic=3.5483698566777244, pvalue=0.00047635326677456235)
# t-test between groups 2008 and 2003:
# Ttest_indResult(statistic=4.4316254594049855, pvalue=1.4326467238244126e-05)
# t-test between groups 2008 and 2004:
# Ttest_indResult(statistic=4.728248896850027, pvalue=3.786277838215774e-06)
# t-test between groups 2008 and 1994:
# Ttest_indResult(statistic=1.3422759927975703, pvalue=0.1810206426386516)
# t-test between groups 2008 and 1998:
# Ttest_indResult(statistic=3.1485803281701337, pvalue=0.001881804018797032)
# t-test between groups 2008 and 1997:
# Ttest_indResult(statistic=2.529099509838452, pvalue=0.012177243025416095)
# t-test between groups 2008 and 1995:
# Ttest_indResult(statistic=nan, pvalue=nan)
# t-test between groups 2008 and 1996:
# Ttest_indResult(statistic=1.6541316336004557, pvalue=0.09966155188197712)
# t-test between groups 2020 and 1999:
# Ttest_indResult(statistic=3.1800602830334053, pvalue=0.0020478519020294904)
# t-test between groups 2020 and 2000:
# Ttest_indResult(statistic=3.2942432452219412, pvalue=0.0014284629375358065)
# t-test between groups 2020 and 2003:
# Ttest_indResult(statistic=5.020504912394246, pvalue=2.023440818697028e-06)
# t-test between groups 2020 and 2004:
# Ttest_indResult(statistic=5.834891595245474, pvalue=4.4651717733630245e-08)
# t-test between groups 2020 and 1994:
# Ttest_indResult(statistic=1.2072624285684708, pvalue=0.23117584491844495)
# t-test between groups 2020 and 1998:
# Ttest_indResult(statistic=2.608385105994134, pvalue=0.010829656088688605)
# t-test between groups 2020 and 1997:
# Ttest_indResult(statistic=2.5183445289302884, pvalue=0.01375995357180078)
# t-test between groups 2020 and 1995:
# Ttest_indResult(statistic=nan, pvalue=nan)
# t-test between groups 2020 and 1996:
# Ttest_indResult(statistic=1.2532944616784836, pvalue=0.21404406890173647)
# t-test between groups 1999 and 2000:
# Ttest_indResult(statistic=0.03337811291666701, pvalue=0.9736185966918129)
# t-test between groups 1999 and 2003:
# Ttest_indResult(statistic=-1.44505354953657, pvalue=0.15480802277064729)
# t-test between groups 1999 and 2004:
# Ttest_indResult(statistic=-1.5871031069741761, pvalue=0.11749611126078595)
# t-test between groups 1999 and 1994:
# Ttest_indResult(statistic=0.15341691014043451, pvalue=0.8802589022043941)
# t-test between groups 1999 and 1998:
# Ttest_indResult(statistic=1.2731288281039794, pvalue=0.2168860919051237)
# t-test between groups 1999 and 1997:
# Ttest_indResult(statistic=-0.3455953979161455, pvalue=0.7330847840073491)
# t-test between groups 1999 and 1995:
# Ttest_indResult(statistic=nan, pvalue=nan)
# t-test between groups 1999 and 1996:
# Ttest_indResult(statistic=1.1520484231624173, pvalue=0.26859495714840664)
# t-test between groups 2000 and 2003:
# Ttest_indResult(statistic=-1.5760890822795879, pvalue=0.1213120599568329)
# t-test between groups 2000 and 2004:
# Ttest_indResult(statistic=-1.6941917274661602, pvalue=0.09509045045874256)
# t-test between groups 2000 and 1994:
# Ttest_indResult(statistic=0.1813951794056891, pvalue=0.8584857981140982)
# t-test between groups 2000 and 1998:
# Ttest_indResult(statistic=1.6106394940118431, pvalue=0.12151417633137249)
# t-test between groups 2000 and 1997:
# Ttest_indResult(statistic=-0.40023749097303946, pvalue=0.6928414947954469)
# t-test between groups 2000 and 1995:
# Ttest_indResult(statistic=nan, pvalue=nan)
# t-test between groups 2000 and 1996:
# Ttest_indResult(statistic=1.5123629856987009, pvalue=0.15122245769992015)
# t-test between groups 2003 and 2004:
# Ttest_indResult(statistic=-0.5409644373802716, pvalue=0.5899305950948021)
# t-test between groups 2003 and 1994:
# Ttest_indResult(statistic=0.7083032011929647, pvalue=0.4831957002614413)
# t-test between groups 2003 and 1998:
# Ttest_indResult(statistic=2.224563870057835, pvalue=0.03128721775310776)
# t-test between groups 2003 and 1997:
# Ttest_indResult(statistic=0.653493077388702, pvalue=0.5168391436463782)
# t-test between groups 2003 and 1995:
# Ttest_indResult(statistic=nan, pvalue=nan)
# t-test between groups 2003 and 1996:
# Ttest_indResult(statistic=1.4594944101778469, pvalue=0.15286780139137882)
# t-test between groups 2004 and 1994:
# Ttest_indResult(statistic=0.7166135103988608, pvalue=0.476881591322053)
# t-test between groups 2004 and 1998:
# Ttest_indResult(statistic=2.0966335078026095, pvalue=0.040397589529395254)
# t-test between groups 2004 and 1997:
# Ttest_indResult(statistic=0.8629612572400408, pvalue=0.3917131807263583)
# t-test between groups 2004 and 1995:
# Ttest_indResult(statistic=nan, pvalue=nan)
# t-test between groups 2004 and 1996:
# Ttest_indResult(statistic=1.314037743894714, pvalue=0.19471345359279446)
# t-test between groups 1994 and 1998:
# Ttest_indResult(statistic=0.9341041439807835, pvalue=0.3746325356559289)
# t-test between groups 1994 and 1997:
# Ttest_indResult(statistic=-0.22323217395489175, pvalue=0.8283391977463843)
# t-test between groups 1994 and 1995:
# Ttest_indResult(statistic=nan, pvalue=nan)
# t-test between groups 1994 and 1996:
# Ttest_indResult(statistic=1.1473614758062882, pvalue=0.3699655471219845)
# t-test between groups 1998 and 1997:
# Ttest_indResult(statistic=-0.9834631652873483, pvalue=0.34001834485659266)
# t-test between groups 1998 and 1995:
# Ttest_indResult(statistic=nan, pvalue=nan)
# t-test between groups 1998 and 1996:
# Ttest_indResult(statistic=1.485003300510917, pvalue=0.17170266143028695)
# t-test between groups 1997 and 1995:
# Ttest_indResult(statistic=nan, pvalue=nan)
# t-test between groups 1997 and 1996:
# Ttest_indResult(statistic=0.7226395368481755, pvalue=0.48825327396915563)
# t-test between groups 1995 and 1996:
# Ttest_indResult(statistic=nan, pvalue=nan)
# ------------------------------------------------
# Comparisons for variable: selling_price with seats
# ------------------------------------------------
# t-test between groups 5 and 4:
# Ttest_indResult(statistic=1.8965862125302206, pvalue=0.057927663757867176)
# t-test between groups 5 and 7:
# Ttest_indResult(statistic=-6.953211393841643, pvalue=3.8763898516274404e-12)
# t-test between groups 5 and 8:
# Ttest_indResult(statistic=0.800587258905609, pvalue=0.4233999479370826)
# t-test between groups 5 and 6:
# Ttest_indResult(statistic=0.452515905978023, pvalue=0.650912911842995)
# t-test between groups 5 and 9:
# Ttest_indResult(statistic=1.3790407744455602, pvalue=0.16793089050119733)
# t-test between groups 5 and 10:
# Ttest_indResult(statistic=1.478877863530954, pvalue=0.13922318747037193)
# t-test between groups 5 and 14:
# Ttest_indResult(statistic=nan, pvalue=nan)
# t-test between groups 5 and 2:
# Ttest_indResult(statistic=-0.11823318268771449, pvalue=0.9058866954118012)
# t-test between groups 4 and 7:
# Ttest_indResult(statistic=-4.722323434425305, pvalue=2.5947299712516263e-06)
# t-test between groups 4 and 8:
# Ttest_indResult(statistic=-0.9453455322805298, pvalue=0.3451061638733932)
# t-test between groups 4 and 6:
# Ttest_indResult(statistic=-0.4877569855573369, pvalue=0.6262755971501535)
# t-test between groups 4 and 9:
# Ttest_indResult(statistic=-0.07786607663288417, pvalue=0.9380083738851396)
# t-test between groups 4 and 10:
# Ttest_indResult(statistic=0.4071876447745949, pvalue=0.6844506552097862)
# t-test between groups 4 and 14:
# Ttest_indResult(statistic=nan, pvalue=nan)
# t-test between groups 4 and 2:
# Ttest_indResult(statistic=-0.19795111686569253, pvalue=0.8433855461585839)
# t-test between groups 7 and 8:
# Ttest_indResult(statistic=5.549767879582316, pvalue=3.4375866767150706e-08)
# t-test between groups 7 and 6:
# Ttest_indResult(statistic=3.0192839179785773, pvalue=0.0025881630361493093)
# t-test between groups 7 and 9:
# Ttest_indResult(statistic=4.641416813510378, pvalue=3.841302952019183e-06)
# t-test between groups 7 and 10:
# Ttest_indResult(statistic=3.397343377844064, pvalue=0.0007039803661089172)
# t-test between groups 7 and 14:
# Ttest_indResult(statistic=nan, pvalue=nan)
# t-test between groups 7 and 2:
# Ttest_indResult(statistic=0.2645069248969457, pvalue=0.7914379953633475)
# t-test between groups 8 and 6:
# Ttest_indResult(statistic=0.08201889898537208, pvalue=0.9346873056802869)
# t-test between groups 8 and 9:
# Ttest_indResult(statistic=1.8899591869085797, pvalue=0.05968722614251345)
# t-test between groups 8 and 10:
# Ttest_indResult(statistic=2.659469287617293, pvalue=0.008327998539651237)
# t-test between groups 8 and 14:
# Ttest_indResult(statistic=nan, pvalue=nan)
# t-test between groups 8 and 2:
# Ttest_indResult(statistic=-0.4123713552754483, pvalue=0.6804431899311734)
# t-test between groups 6 and 9:
# Ttest_indResult(statistic=2.4404480667217636, pvalue=0.015918411268462773)
# t-test between groups 6 and 10:
# Ttest_indResult(statistic=4.255370662041148, pvalue=5.691125500899815e-05)
# t-test between groups 6 and 14:
# Ttest_indResult(statistic=nan, pvalue=nan)
# t-test between groups 6 and 2:
# Ttest_indResult(statistic=-0.7530694388764274, pvalue=0.4542582891618815)
# t-test between groups 9 and 10:
# Ttest_indResult(statistic=3.4477884763242477, pvalue=0.00083747148146602)
# t-test between groups 9 and 14:
# Ttest_indResult(statistic=nan, pvalue=nan)
# t-test between groups 9 and 2:
# Ttest_indResult(statistic=-1.5952962226492382, pvalue=0.11458920340324427)
# t-test between groups 10 and 14:
# Ttest_indResult(statistic=nan, pvalue=nan)
# t-test between groups 10 and 2:
# Ttest_indResult(statistic=-2.730482812096079, pvalue=0.013284870866724002)
# t-test between groups 14 and 2:
# Ttest_indResult(statistic=nan, pvalue=nan)

# %% [markdown]
# The t-tests indicate that some differences are statistically significant and some are not.

# %% [markdown]
# ### Bivariate analysis of two categorical variables

# %%
# Creating Categorical usedcar dataset
usedcars_cat_df = pd.DataFrame()
for col in usedcars_cat_list:
    usedcars_cat_df[col]=usedcars_df[col]

# %%
usedcars_cat_df
# Out:
#       year  seats
# 0     2014      5
# 1     2014      5
# 2     2006      5
# 3     2010      5
# 4     2007      5
# ...    ...    ...
# 7901  2013      5
# 7902  2007      5
# 7903  2009      5
# 7904  2013      5
# 7905  2013      5
#
# [7906 rows x 2 columns]

# %% [markdown]
# Looks like the difference are visually and satistically significant.
#
# ### Feature Engineering
#
# #### Working with categorical variables

# %%
dummy_usedcars_cat_df = pd.get_dummies(usedcars_cat_df, drop_first=True)

# %%
log_usedcars_df = pd.concat([log_usedcars_df, dummy_usedcars_cat_df], axis=1)

# %%
log_usedcars_df
# Out:
#        mileage    engine  max_power  selling_price  year  seats
# 0     3.152736  7.129298   4.304065         450000  2014      5
# 1     3.051167  7.311886   4.639765         370000  2014      5
# 2     2.873565  7.311218   4.356709         158000  2006      5
# 3     3.135494  7.241366   4.499810         225000  2010      5
# 4     2.778819  7.168580   4.479607         130000  2007      5
# ...        ...       ...        ...            ...   ...    ...
# 7901  2.917771  7.087574   4.417032         320000  2013      5
# 7902  2.821379  7.308543   4.700480         135000  2007      5
# 7903  2.960105  7.129298   4.302713         382000  2009      5
# 7904  3.159975  7.241366   4.248495         290000  2013      5
# 7905  3.159975  7.241366   4.248495         290000  2013      5
#
# [7906 rows x 6 columns]

# %% [markdown]
# #### Dealing with Non Normality

# %%
# Histograms of the log-transformed data
fig = plt.figure(figsize=(20,30))
for i, col in enumerate(usedcars_col_list):
    plt.subplot(len(usedcars_col_list), 4, i+1)
    print(col)
    plt.hist(log_usedcars_df[col])
    plt.title("Boxcox Histogram {}".format(col))
    
plt.show()
# Out:
# selling_price
# mileage
# engine
# max_power

# %%
# jarque_bera &  normaltest of the log-transformed data
fig = plt.figure(figsize=(20,30))
for col in usedcars_col_list:
    print(col)
    jb_stats = jarque_bera(log_usedcars_df[col])
    norm_stats = normaltest(log_usedcars_df[col])
    print("Jarque-Bera test statistics is {0} and p value is {1}".format(jb_stats[0], jb_stats[1]))
    print("Normality test statistics is {0} and p value is {1}".format(norm_stats[0], norm_stats[1]))
    print("--------------------------")
# Out:
# selling_price
# Jarque-Bera test statistics is 162830.687642466 and p value is 0.0
# Normality test statistics is 6745.807948635 and p value is 0.0
# --------------------------
# mileage
# Jarque-Bera test statistics is 256.4068503284236 and p value is 0.0
# Normality test statistics is 238.57453459464395 and p value is 1.5638606479361165e-52
# --------------------------
# engine
# Jarque-Bera test statistics is 238.54955689271415 and p value is 0.0
# Normality test statistics is 223.45702814691595 and p value is 2.9986298967055847e-49
# --------------------------
# max_power
# Jarque-Bera test statistics is 289.6577277883083 and p value is 0.0
# Normality test statistics is 241.00216163688407 and p value is 4.6456398369651755e-53
# --------------------------

# %% [markdown]
# for few variables the p-values are 0, which indicates that the distribution of the log-transformed variables is statistically different from the normal distribution. However, these transformations might still be useful.
#
# #### Appying Boxcox Transformation

# %%
# Histograms of the boxcox transformed data

fig = plt.figure(figsize=(20,30))
for i, col in enumerate(usedcars_col_list):
    plt.subplot(len(usedcars_col_list), 4, i+1)
    col_boxcox,_ = boxcox(usedcars_df[col])
    plt.hist(col_boxcox)
    plt.title("histogram of {} (box-cox transformed)".format(col))
    
plt.show()

# %% [markdown]
# The result was similar to the log transformed data but with boxcox the selling prices is now close to normal distribution. Not all are statisically normal distribution.
#
# ### PCA - Principal Component Analysis

# %%
pca_list = ['mileage', 'engine', 'max_power']
fig = plt.figure(figsize=(20,20))
for i, col in enumerate(pca_list):
    plt.subplot(len(pca_list), 4, i+1)
    t = sns.regplot(
        'selling_price',
        col,
        log_usedcars_df,
        x_jitter=.49,
        y_jitter=.49,
        fit_reg=False
    )
    t.axhline(0, color='k', linestyle='-', linewidth=2)
    t.axvline(0, color='k', linestyle='-', linewidth=2)
    t.axes.set_title('Raw data')
plt.show()

# %%
# Standardize the variables by subtracting the mean and dividing by the standard
# deviation, so that both variables are on the same scale.
pca_list_z = [  'mileage_z', 'engine_z', 'max_power_z']
log_usedcars_st_df = pd.DataFrame()
log_usedcars_st_df['selling_price_z'] = (log_usedcars_df['selling_price'] - log_usedcars_df['selling_price'].mean()) / log_usedcars_df['selling_price'].std()
for col in pca_list:
    log_usedcars_st_df[col] = (log_usedcars_df[col] - log_usedcars_df[col].mean()) / log_usedcars_df[col].std()

log_usedcars_st_df.rename(columns={'mileage':'mileage_z', 'engine':'engine_z', 'max_power':'max_power_z'}, inplace=True)
fig = plt.figure(figsize=(20,30))
for i, col in enumerate(pca_list_z):
    plt.subplot(len(pca_list_z), 4, i+1)
    t = sns.regplot(
        'selling_price_z',
        col,
        log_usedcars_st_df,
        x_jitter=.49,
        y_jitter=.49,
        fit_reg=False
    )
    t.axhline(0, color='k', linestyle='-', linewidth=2)
    t.axvline(0, color='k', linestyle='-', linewidth=2)
    t.axes.set_title('Standardized data')
plt.show()

# %%
fig = plt.figure(figsize=(20,30))
for i, col in enumerate(pca_list_z):
    plt.subplot(len(pca_list_z), 4, i+1)
    t = sns.regplot(
        'selling_price_z',
        col,
        log_usedcars_st_df,
        x_jitter=.49,
        y_jitter=.49,
        fit_reg=False
    )
    t.axhline(0, color='k', linestyle='-', linewidth=2)
    t.axvline(0, color='k', linestyle='-', linewidth=2)
    t.axes.set_title('Standardized data')
    
    sns.regplot('selling_price_z', 
            col, 
            log_usedcars_st_df, 
            scatter=False, 
            color="red")
    
plt.show()

# %%
# Rotating the data so that the axes roughly match to the vector above
pca_list_z_rot = ['mileage_z_rot', 'engine_z_rot', 'max_power_z_rot']

log_usedcars_st_rt_df = pd.DataFrame()
log_usedcars_st_rt_df['selling_price_z_rot'] = math.cos(40) * log_usedcars_st_df['selling_price_z'] - math.sin(40) * log_usedcars_st_df['selling_price_z']
for col in pca_list_z:
    log_usedcars_st_rt_df[col] = math.sin(40) * log_usedcars_st_df[col] + math.cos(40) * log_usedcars_st_df[col]

log_usedcars_st_rt_df.rename(columns={ 'mileage_z':'mileage_z_rot', 'engine_z':'engine_z_rot', 'max_power_z':'max_power_z_rot'}, inplace=True)

fig = plt.figure(figsize=(20,20))
for i, col in enumerate(pca_list_z_rot):
    plt.subplot(len(pca_list_z_rot), 4, i+1)
    t = sns.regplot(
        'selling_price_z_rot',
        col,
        log_usedcars_st_rt_df,
        x_jitter=.49,
        y_jitter=.49,
        fit_reg=False
    )
    t.axhline(0, color='k', linestyle='-', linewidth=2)
    t.axvline(0, color='k', linestyle='-', linewidth=2)
    t.axes.set_title('Rotated Standardized data')
plt.show()

# %% [markdown]
# Based on the PCA (Principal component analysis) the Variance on horizontal vectors span is higher than vertical vector, which means dropping horizontal axis we would lose less than 50% of the information.
#
# #### Calculating Eigenvalues and Eigenvectors

# %%
X = StandardScaler().fit_transform(log_usedcars_df)

# The NumPy covariance function assumes that variables are represented by rows,
# not columns. So transpose `X`.
Xt = X.T
Cx = np.cov(Xt)
print('Covariance Matrix:\n', Cx)

# Calculating eigenvalues and eigenvectors
eig_val_cov, eig_vec_cov = np.linalg.eig(Cx)

# Inspecting the eigenvalues and eigenvectors.
for i in range(len(eig_val_cov)):
    eigvec_cov = eig_vec_cov[:, i].T
    print('Eigenvector {}: \n{}'.format(i + 1, eigvec_cov))
    print('Eigenvalue {}: {}'.format(i + 1, eig_val_cov[i]))
    print(40 * '-')

print(
    'The proportion of total variance in the dataset explained by each',
    'component calculated by hand\n',
    eig_val_cov / sum(eig_val_cov)
)
# Out:
# Covariance Matrix:
#  [[ 1.0001265  -0.59145398 -0.38536443 -0.13893174  0.32917071 -0.50619601]
#  [-0.59145398  1.0001265   0.76167184  0.45250498  0.0496074   0.57391703]
#  [-0.38536443  0.76167184  1.0001265   0.65632217  0.26506253  0.22470492]
#  [-0.13893174  0.45250498  0.65632217  1.0001265   0.41235372  0.04162196]
#  [ 0.32917071  0.0496074   0.26506253  0.41235372  1.0001265  -0.00792403]
#  [-0.50619601  0.57391703  0.22470492  0.04162196 -0.00792403  1.0001265 ]]
# Eigenvector 1:
# [ 0.39523682 -0.55023199 -0.50948777 -0.38149992 -0.10246929 -0.35413652]
# Eigenvalue 1: 2.8226045200466556
# ----------------------------------------
# Eigenvector 2:
# [-0.45719541  0.09308757 -0.22698628 -0.45881952 -0.63143751  0.34864826]
# Eigenvalue 2: 1.6304370081090183
# ----------------------------------------
# Eigenvector 3:
# [-0.18795603 -0.01138935  0.26504859  0.27832431 -0.55636727 -0.71223809]
# Eigenvalue 3: 0.7696462014883227
# ----------------------------------------
# Eigenvector 4:
# [-0.48061317 -0.42922356 -0.45822388  0.59261449  0.08828017  0.12579214]
# Eigenvalue 4: 0.3478348281839007
# ----------------------------------------
# Eigenvector 5:
# [-0.60654155 -0.11220935  0.14416194 -0.46070582  0.50663409 -0.36028571]
# Eigenvalue 5: 0.30114267429191177
# ----------------------------------------
# Eigenvector 6:
# [ 0.02347491 -0.70116042  0.62281369 -0.05510218 -0.12950167  0.31641613]
# Eigenvalue 6: 0.12909378116292217
# ----------------------------------------
# The proportion of total variance in the dataset explained by each component calculated by hand
#  [0.47037458 0.27170513 0.12825814 0.05796514 0.0501841  0.02151291]

# %%
# Print scree plot
plt.plot(eig_val_cov)
plt.show()

print(eig_val_cov)
# Out:
# [2.82260452 1.63043701 0.7696462  0.34783483 0.30114267 0.12909378]

# %% [markdown]
# Both the scree plot and the eigenvalues-greater-than-1 rule agree that you should keep 2 components.

# %%
# Scikit-learn PCA function

sklearn_pca = PCA(n_components=2)
Y_sklearn = sklearn_pca.fit_transform(X)

P = eig_vec_cov[:, 0]

# Transform `X` into `Y`.
Y = P.T.dot(Xt)

print(
    'The percentage of total variance in the dataset explained by each',
    'component from Sklearn PCA.\n',
    sklearn_pca.explained_variance_ratio_
)

# Compare the scikit-learn solution to yours—it's a perfect match!
plt.plot(Y_sklearn[:, 0], Y, 'o')
plt.title('Comparing solutions')
plt.ylabel('Sklearn Component 1')
plt.xlabel('By-hand Component 1')
plt.show()
# Out:
# The percentage of total variance in the dataset explained by each component from Sklearn PCA.
#  [0.47037458 0.27170513]

# %% [markdown]
# #### Summary
#
# As per the PCA Analysis the principal components are 6 out of 8 variables.
# They are selling_price, km_driven, mileage, fuel, seller_type, transmission & owner

# %%
# Checking Variance Inflation Factor

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif_data = pd.DataFrame()
vif_data["features"]=log_usedcars_df.columns
vif_data["VIF"]=[variance_inflation_factor(log_usedcars_df.values, i)
                          for i in range(len(log_usedcars_df.columns))]
vif_data
# Out:
#         features          VIF
# 0        mileage   346.681110
# 1         engine  2218.228988
# 2      max_power   596.976638
# 3  selling_price     2.936440
# 4           year  2057.602437
# 5          seats    61.524561

# %% [markdown]
# #### Create Training and Testing Data sets

# %%
# Split Scaled log transformed df_data into Test and Train data
X = log_usedcars_df.drop(['selling_price'],axis=1)
y = log_usedcars_df['selling_price']
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.20,random_state=465)

# %% [markdown]
# ## Modeling
#
# #### OLS Regression

# %%
X_train = sm.add_constant(X_train)

# Fit an OLS model using statsmodels
results = sm.OLS(y_train, X_train).fit()

# Print the summary results
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          selling_price   R-squared:                       0.506
# Model:                            OLS   Adj. R-squared:                  0.505
# Method:                 Least Squares   F-statistic:                     1292.
# Date:                Tue, 11 Oct 2022   Prob (F-statistic):               0.00
# Time:                        02:35:11   Log-Likelihood:                -92798.
# No. Observations:                6324   AIC:                         1.856e+05
# Df Residuals:                    6318   BIC:                         1.856e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.224e+08   4.46e+06    -27.440      0.000   -1.31e+08   -1.14e+08
# mileage    -1.752e+05   4.99e+04     -3.509      0.000   -2.73e+05   -7.73e+04
# engine      2.861e+05   4.77e+04      5.993      0.000    1.93e+05     3.8e+05
# max_power   1.198e+06   3.78e+04     31.697      0.000    1.12e+06    1.27e+06
# year        5.806e+04   2261.156     25.676      0.000    5.36e+04    6.25e+04
# seats      -1.389e+05   1.05e+04    -13.199      0.000    -1.6e+05   -1.18e+05
# ==============================================================================
# Omnibus:                     4768.561   Durbin-Watson:                   1.980
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           106842.095
# Skew:                           3.445   Prob(JB):                         0.00
# Kurtosis:                      21.921   Cond. No.                     1.25e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.25e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Add a constant to the model because it's best practice
# to do so every time!
X_test = sm.add_constant(X_test)

# You are making predictions here
ols_y_preds = results.predict(X_test)

plt.scatter(y_test, ols_y_preds)
plt.plot(y_test, y_test, color="red")
plt.xlabel("true values")
plt.ylabel("predicted values")
plt.title("Charges: true and predicted values")
plt.show()

# %% [markdown]
# #### Linear Regression

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

print("The number of observations in training set is {}".format(X_train.shape[0]))
print("The number of observations in test set is {}".format(X_test.shape[0]))

# You are making predictions here
y_preds_train = lr.predict(X_train)
y_preds_test = lr.predict(X_test)

print("R-squared of the model in the training set is: {}".format(lr.score(X_train, y_train)))
print("-----Test set statistics-----")
print("R-squared of the model in the test set is: {}".format(lr.score(X_test, y_test)))
print("Mean absolute error of the prediction is: {}".format(mean_absolute_error(y_test, y_preds_test)))
print("Mean squared error of the prediction is: {}".format(mse(y_test, y_preds_test)))
print("Root mean squared error of the prediction is: {}".format(rmse(y_test, y_preds_test)))
print("Mean absolute percentage error of the prediction is: {}".format(np.mean(np.abs((y_test - y_preds_test) / y_test)) * 100))

# k-Fold Cross Validation
cv_score = cross_val_score(estimator = lr, X = X_train, y = y_train, cv = 5)
print("Cross Validation Score is: {}".format(cv_score.mean()))
# Out:
# The number of observations in training set is 6324
# The number of observations in test set is 1582
# R-squared of the model in the training set is: 0.5056514837179752
# -----Test set statistics-----
# R-squared of the model in the test set is: 0.5010521922407017
# Mean absolute error of the prediction is: 333819.09781244426
# Mean squared error of the prediction is: 335100549101.805
# Root mean squared error of the prediction is: 578878.6998169867
# Mean absolute percentage error of the prediction is: 97.24736094187651
# Cross Validation Score is: 0.5031154416143269

# %% [markdown]
# #### Ridge Regression

# %%
# Creating regularization parameter
alphas = [np.power(10.0,p) for p in np.arange(-10,40,1)]

# Fitting a ridge regression model. Here, `alpha` is the regularization
# parameter (usually called `lambda`). As `alpha` gets larger, parameter
# shrinkage grows more pronounced.
ridgeregr = RidgeCV(alphas=alphas, cv=5) 
ridgeregr.fit(X_train, y_train)

# You are making predictions here
ridge_y_preds_train = ridgeregr.predict(X_train)
ridge_y_preds_test = ridgeregr.predict(X_test)

print("R-squared of the model on the training set is: {}".format(ridgeregr.score(X_train, y_train)))
print("-----Test set statistics-----")
print("R-squared of the model on the test set is: {}".format(ridgeregr.score(X_test, y_test)))
print("Mean absolute error of the prediction is: {}".format(mean_absolute_error(y_test, ridge_y_preds_test)))
print("Mean squared error of the prediction is: {}".format(mse(y_test, ridge_y_preds_test)))
print("Root mean squared error of the prediction is: {}".format(rmse(y_test, ridge_y_preds_test)))
print("Mean absolute percentage error of the prediction is: {}".format(np.mean(np.abs((y_test - ridge_y_preds_test) / y_test)) * 100))

# k-Fold Cross Validation
cv_score = cross_val_score(estimator = ridgeregr, X = X_train, y = y_train, cv = 5)
print("Cross Validation Score is: {}".format(cv_score.mean()))
# Out:
# R-squared of the model on the training set is: 0.5056506279123907
# -----Test set statistics-----
# R-squared of the model on the test set is: 0.5010618106785473
# Mean absolute error of the prediction is: 333656.6122499046
# Mean squared error of the prediction is: 335094089220.12317
# Root mean squared error of the prediction is: 578873.1201395718
# Mean absolute percentage error of the prediction is: 97.17539280086078
# Cross Validation Score is: 0.5031269021391495

# %% [markdown]
# #### Lasso Regression

# %%
lassoregr = LassoCV(alphas=alphas, cv=5) 
lassoregr.fit(X_train, y_train)

# You are making predictions here
lasso_y_preds_train = lassoregr.predict(X_train)
lasso_y_preds_test = lassoregr.predict(X_test)

print("R-squared of the model on the training set is: {}".format(lassoregr.score(X_train, y_train)))
print("-----Test set statistics-----")
print("R-squared of the model on the test set is: {}".format(lassoregr.score(X_test, y_test)))
print("Mean absolute error of the prediction is: {}".format(mean_absolute_error(y_test, lasso_y_preds_test)))
print("Mean squared error of the prediction is: {}".format(mse(y_test, lasso_y_preds_test)))
print("Root mean squared error of the prediction is: {}".format(rmse(y_test, lasso_y_preds_test)))
print("Mean absolute percentage error of the prediction is: {}".format(np.mean(np.abs((y_test - lasso_y_preds_test) / y_test)) * 100))

# k-Fold Cross Validation
cv_score = cross_val_score(estimator = lassoregr, X = X_train, y = y_train, cv = 5)
print("Cross Validation Score is: {}".format(cv_score.mean()))
# Out:
# R-squared of the model on the training set is: 0.5056514837179737
# -----Test set statistics-----
# R-squared of the model on the test set is: 0.5010521922406975
# Mean absolute error of the prediction is: 333819.0978124282
# Mean squared error of the prediction is: 335100549101.80786
# Root mean squared error of the prediction is: 578878.6998169891
# Mean absolute percentage error of the prediction is: 97.24736094187153
# Cross Validation Score is: 0.5031226762333397

# %% [markdown]
# #### ElasticNet Regression

# %%
elasticregr = ElasticNetCV(alphas=alphas, cv=5) 
elasticregr.fit(X_train, y_train)

# You are making predictions here
y_preds_train = elasticregr.predict(X_train)
elasticy_preds_test = elasticregr.predict(X_test)

print("R-squared of the model on the training set is: {}".format(elasticregr.score(X_train, y_train)))
print("-----Test set statistics-----")
print("R-squared of the model on the test set is: {}".format(elasticregr.score(X_test, y_test)))
print("Mean absolute error of the prediction is: {}".format(mean_absolute_error(y_test, elasticy_preds_test)))
print("Mean squared error of the prediction is: {}".format(mse(y_test, elasticy_preds_test)))
print("Root mean squared error of the prediction is: {}".format(rmse(y_test, elasticy_preds_test)))
print("Mean absolute percentage error of the prediction is: {}".format(np.mean(np.abs((y_test - elasticy_preds_test) / y_test)) * 100))

# k-Fold Cross Validation
cv_score = cross_val_score(estimator = elasticregr, X = X_train, y = y_train, cv = 5)
print("Cross Validation Score is: {}".format(cv_score.mean()))
# Out:
# R-squared of the model on the training set is: 0.5056431639395109
# -----Test set statistics-----
# R-squared of the model on the test set is: 0.5010769846833516
# Mean absolute error of the prediction is: 333314.89219964825
# Mean squared error of the prediction is: 335083898139.4872
# Root mean squared error of the prediction is: 578864.3175559253
# Mean absolute percentage error of the prediction is: 97.0214517349378
# Cross Validation Score is: 0.5031391258705902

# %% [markdown]
# #### KNN Regressor

# %%
knn = neighbors.KNeighborsRegressor(n_neighbors=10)
knn.fit(X_train, y_train)

# You are making predictions here
knn_y_preds_train = knn.predict(X_train)
knn_y_preds_test = knn.predict(X_test)

print("R-squared of the model on the training set is: {}".format(elasticregr.score(X_train, y_train)))
print("-----Test set statistics-----")
print("R-squared of the model on the test set is: {}".format(elasticregr.score(X_test, y_test)))
print("Mean absolute error of the prediction is: {}".format(mean_absolute_error(y_test, elasticy_preds_test)))
print("Mean squared error of the prediction is: {}".format(mse(y_test, elasticy_preds_test)))
print("Root mean squared error of the prediction is: {}".format(rmse(y_test, elasticy_preds_test)))
print("Mean absolute percentage error of the prediction is: {}".format(np.mean(np.abs((y_test - elasticy_preds_test) / y_test)) * 100))

# k-Fold Cross Validation
cv_score = cross_val_score(estimator = knn, X = X_train, y = y_train, cv = 5)
print("Cross Validation Score is: {}".format(cv_score.mean()))
# Out:
# R-squared of the model on the training set is: 0.5056431639395109
# -----Test set statistics-----
# R-squared of the model on the test set is: 0.5010769846833516
# Mean absolute error of the prediction is: 333314.89219964825
# Mean squared error of the prediction is: 335083898139.4872
# Root mean squared error of the prediction is: 578864.3175559253
# Mean absolute percentage error of the prediction is: 97.0214517349378
# Cross Validation Score is: 0.9051729151650534

# %%
# Plotting the training data and the prediction line for the newly generated loudness values
plt.scatter(X_train['engine'], y_train, c='k', label='data')
plt.plot(X_test['engine'], knn_y_preds_test, c='g', label='prediction')
plt.legend()
plt.title('K=10, Unweighted')
plt.show()

# %% [markdown]
# #### Decision Tree Regressor

# %%
decisiontreeregr = DecisionTreeRegressor() 
decisiontreeregr.fit(X_train, y_train)

# You are making predictions here
deci_y_preds_train = decisiontreeregr.predict(X_train)
deci_y_preds_test = decisiontreeregr.predict(X_test)

print("R-squared of the model on the training set is: {}".format(decisiontreeregr.score(X_train, y_train)))
print("-----Test set statistics-----")
print("R-squared of the model on the test set is: {}".format(decisiontreeregr.score(X_test, y_test)))
print("Mean absolute error of the prediction is: {}".format(mean_absolute_error(y_test, deci_y_preds_test)))
print("Mean squared error of the prediction is: {}".format(mse(y_test, deci_y_preds_test)))
print("Root mean squared error of the prediction is: {}".format(rmse(y_test, deci_y_preds_test)))
print("Mean absolute percentage error of the prediction is: {}".format(np.mean(np.abs((y_test - deci_y_preds_test) / y_test)) * 100))

# k-Fold Cross Validation
cv_score = cross_val_score(estimator = decisiontreeregr, X = X_train, y = y_train, cv = 5)
print("Cross Validation Score is: {}".format(cv_score.mean()))
# Out:
# R-squared of the model on the training set is: 0.9940923918902153
# -----Test set statistics-----
# R-squared of the model on the test set is: 0.9751763449023895
# Mean absolute error of the prediction is: 71020.16230613574
# Mean squared error of the prediction is: 16671925048.192745
# Root mean squared error of the prediction is: 129119.8088915591
# Mean absolute percentage error of the prediction is: 15.08279858954769
# Cross Validation Score is: 0.9393455269328068

# %% [markdown]
# #### Random Forest Regressor

# %%
randomregr = RandomForestRegressor() 
randomregr.fit(X_train, y_train)

# You are making predictions here
random_y_preds_train = randomregr.predict(X_train)
random_y_preds_test = randomregr.predict(X_test)

print("R-squared of the model on the training set is: {}".format(randomregr.score(X_train, y_train)))
print("-----Test set statistics-----")
print("R-squared of the model on the test set is: {}".format(randomregr.score(X_test, y_test)))
print("Mean absolute error of the prediction is: {}".format(mean_absolute_error(y_test, random_y_preds_test)))
print("Mean squared error of the prediction is: {}".format(mse(y_test, random_y_preds_test)))
print("Root mean squared error of the prediction is: {}".format(rmse(y_test, random_y_preds_test)))
print("Mean absolute percentage error of the prediction is: {}".format(np.mean(np.abs((y_test - random_y_preds_test) / y_test)) * 100))

# k-Fold Cross Validation
cv_score = cross_val_score(estimator = randomregr, X = X_train, y = y_train, cv = 5)
print("Cross Validation Score is: {}".format(cv_score.mean()))
# Out:
# R-squared of the model on the training set is: 0.9905819745740035
# -----Test set statistics-----
# R-squared of the model on the test set is: 0.9817783646997388
# Mean absolute error of the prediction is: 66444.17025145375
# Mean squared error of the prediction is: 12237913264.058386
# Root mean squared error of the prediction is: 110625.10232338042
# Mean absolute percentage error of the prediction is: 14.350596187427152
# Cross Validation Score is: 0.9614069402629308

# %% [markdown]
# #### Random Forest Regressor with Hyperparameter Tuning

# %%
RandomForestRegressor().get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
randomregr = RandomForestRegressor(n_estimators=200,
                                  min_samples_split=5,
                                  min_samples_leaf=1,
                                  max_features='sqrt',
                                  max_depth=60,
                                  bootstrap=False) 
randomregr.fit(X_train, y_train)

# You are making predictions here
randomh_y_preds_train = randomregr.predict(X_train)
randomh_y_preds_test = randomregr.predict(X_test)

print("R-squared of the model on the training set is: {}".format(randomregr.score(X_train, y_train)))
print("-----Test set statistics-----")
print("R-squared of the model on the test set is: {}".format(randomregr.score(X_test, y_test)))
print("Mean absolute error of the prediction is: {}".format(mean_absolute_error(y_test, randomh_y_preds_test)))
print("Mean squared error of the prediction is: {}".format(mse(y_test, randomh_y_preds_test)))
print("Root mean squared error of the prediction is: {}".format(rmse(y_test, randomh_y_preds_test)))
print("Mean absolute percentage error of the prediction is: {}".format(np.mean(np.abs((y_test - randomh_y_preds_test) / y_test)) * 100))

# k-Fold Cross Validation
cv_score = cross_val_score(estimator = randomregr, X = X_train, y = y_train, cv = 5)
print("Cross Validation Score is: {}".format(cv_score.mean()))
# Out:
# R-squared of the model on the training set is: 0.992771850569675
# -----Test set statistics-----
# R-squared of the model on the test set is: 0.981336341217256
# Mean absolute error of the prediction is: 66157.11952444325
# Mean squared error of the prediction is: 12534782614.704607
# Root mean squared error of the prediction is: 111958.8433966009
# Mean absolute percentage error of the prediction is: 14.189859921655918
# Cross Validation Score is: 0.9613544602117339

# %% [markdown]
# #### Compare Predicted Values of each Model

# %%
compare = pd.DataFrame()
compare['selling_price'] = y_test
compare['ols_y_preds'] = ols_y_preds
compare['lr_preds_test'] = y_preds_test
compare['ridge_y_preds_test'] = ridge_y_preds_test
compare['lasso_y_preds_test'] = lasso_y_preds_test
compare['elastic_y_preds_test'] = elasticy_preds_test
compare['knn_y_preds_test'] = knn_y_preds_test
compare['deci_y_preds_test'] = deci_y_preds_test
compare['random_y_preds_test'] = random_y_preds_test
compare['randomh_y_preds_test'] = randomh_y_preds_test

# %%
compare
# Out:
#       selling_price   ols_y_preds  lr_preds_test  ridge_y_preds_test  \
# 4047         400000  4.095648e+05   4.095648e+05        4.098198e+05
# 90           175000  3.641002e+04   3.641002e+04        3.605379e+04
# 3633         149000  5.259618e+05   5.259618e+05        5.253759e+05
# 7830         599000  1.285307e+06   1.285307e+06        1.284551e+06
# 5529         165000 -1.271359e+05  -1.271359e+05       -1.271530e+05
# ...             ...           ...            ...                 ...
# 4897         600000  1.198634e+06   1.198634e+06        1.197753e+06
# 4377         350000  2.208149e+05   2.208149e+05        2.214151e+05
# 116         1140000  1.317476e+06   1.317476e+06        1.316698e+06
# 1031         440000  1.436496e+06   1.436496e+06        1.435670e+06
# 7256         600000  1.061113e+06   1.061113e+06        1.060588e+06
#
#       lasso_y_preds_test  elastic_y_preds_test  knn_y_preds_test  \
# 4047        4.095648e+05          4.103582e+05          403499.9
# 90          3.641002e+04          3.532093e+04          186000.0
# 3633        5.259618e+05          5.241391e+05          274200.0
# 7830        1.285307e+06          1.282941e+06          818400.0
# 5529       -1.271359e+05         -1.271786e+05          117500.0
# ...                  ...                   ...               ...
# 4897        1.198634e+06          1.195899e+06          711500.0
# 4377        2.208149e+05          2.227233e+05          326900.0
# 116         1.317476e+06          1.315038e+06          939499.8
# 1031        1.436496e+06          1.433868e+06          393700.0
# 7256        1.061113e+06          1.059467e+06          592100.0
#
#       deci_y_preds_test  random_y_preds_test  randomh_y_preds_test
# 4047      396590.772727        395030.912138         396590.772727
# 90        160000.000000        156410.236419         157121.490083
# 3633      295000.000000        285876.839048         292102.083333
# 7830      770500.000000        832638.465368         753710.000000
# 5529      116250.000000        115566.527778         116243.750000
# ...                 ...                  ...                   ...
# 4897      718833.333333        720367.939336         718833.333333
# 4377      336666.666667        335396.616855         336666.666667
# 116       935908.909091        936592.524128         935908.909091
# 1031      435000.000000        418178.809524         442393.333333
# 7256      600000.000000        608700.000000         618930.396667
#
# [1582 rows x 10 columns]

# %% [markdown]
# ### Summary:
# Among all the Random Forest Regressor has the highest R-Squared Value which makes it the best.
